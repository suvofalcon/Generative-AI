# %% [markdown]
# # Translation and Summary of Foreign News
#
# The goal of this project will be to get a summary of news in foreign countries by automatically scraping a newspapers headlines or articles, and then translating the text with OpenAI and also providing a summary format.
#
# ## Data (Web Scraping)
#
# Let's explore how we could set-up a scraping job (note this has its limits, not every website can be easily scraped, your results may vary on other newpaper sites).

# %%
import requests
import bs4
import os
import openai

# %%
# This is just a limited example dictionary - We will build this dictionary of the common international news sites
# As each website is different, this gets harder with more countries!
country_newspapers = {"Spain":'https://elpais.com/',
                      "France":"https://www.lemonde.fr/",
                      "Netherlands":"https://www.deutschland.de/de/"
                      }

# %%
country = input("What country are you interested in for a news summary? ")

# %%
url = country_newspapers[country]
url
# Out:
# 'https://www.lemonde.fr/'

# %% [markdown]
# ### Parsing HTML

# %%
result = requests.get(url)
soup = bs4.BeautifulSoup(result.text, "lxml")

# %%
soup.select('.article__title-label')
# Out:
# [<p class="article__title-label">Des rescapés du massacre de la rave-party en Israël témoignent : « On ne voyait pas comment s’en tirer »</p>]

# %%
soup  # See the entire parsed text
# Out:
# <!DOCTYPE html>
# <html lang="fr" prefix="og: http://ogp.me/ns#"> <head> <meta charset="utf-8"/> <meta content="IE=edge" http-equiv="X-UA-Compatible"/> <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/> <meta content="no-referrer-when-downgrade" name="referrer"/> <meta content="#ffffff" name="theme-color"/> <script async="1" data-gdpr-purposes="personalization" data-gdpr-src="//www.lemonde.fr/bucket/assets/9b6e1d3a1d035999ff750fe3b08fe717b62420d7/js/chartbeatMab.bundle.js" type="text/plain"></script> <link data-rh="true" href="https://www.lemonde.fr/en/" hreflang="en-US" rel="alternate"/> <link data-rh="true" href="https://www.lemonde.fr/en/" hreflang="en" rel="alternate"/> <link data-rh="true" href="https://www.lemonde.fr/en/" hreflang="en-CA" rel="alternate"/> <link data-rh="true" href="https://www.lemonde.fr/en/" hreflang="en-GB" rel="alternate"/> <link href="//img.lemde.fr" rel="preconnect"/> <link as="image" fetchpriority="high" imagesizes="100vw" imagesrcset=" https://img.lemde.fr/2023/10/09/0/165/2169/1446/400/266/75/0/1158aaf_5528669-01-06.jpg 400w, https://img.lemde.fr/2023/10/09/0/165/2169/1446/500/333/75/0/1158aaf_5528669-01-06.jpg 500w, https://img.lemde.fr/2023/10/09/0/165/2169/1446/600/400/75/0/1158aaf_5528669-01-06.jpg 600w, https://img.lemde.fr/2023/10/09/0/165/2169/1446/700/466/75/0/1158aaf_5528669-01-06.jpg 700w, https://img.lemde.fr/2023/10/09/0/165/2169/1446/800/533/75/0/1158aaf_5528669-01-06.jpg 800w" media="(max-width: 575px)" rel="preload"/> <link as="image" fetchpriority="high" imagesizes="100vw" imagesrcset=" https://img.lemde.fr/2023/10/09/167/0/2500/1250/600/300/75/0/1158aaf_5528669-01-06.jpg 600w, https://img.lemde.fr/2023/10/09/167/0/2500/1250/700/350/75/0/1158aaf_5528669-01-06.jpg 700w, https://img.lemde.fr/2023/10/09/167/0/2500/1250/800/400/75/0/1158aaf_5528669-01-06.jpg 800w" media="(min-width: 576px) and (max-width: 1023px)" rel="preload"/> <link as="image" fetchpriority="high" imagesizes="644px" imagesrcset=" https://img.lemde.fr/2023/10/09/167/0/2500/1250/500/250/75/0/1158aaf_5528669-01-06.jpg 500w, https://img.lemde.fr/2023/10/09/167/0/2500/1250/600/300/75/0/1158aaf_5528669-01-06.jpg 600w, https://img.lemde.fr/2023/10/09/167/0/2500/1250/700/350/75/0/1158aaf_5528669-01-06.jpg 700w, https://img.lemde.fr/2023/10/09/167/0/2500/1250/800/400/75/0/1158aaf_5528669-01-06.jpg 800w, https://img.lemde.fr/2023/10/09/167/0/2500/1250/900/450/75/0/1158aaf_5528669-01-06.jpg 900w" media="(min-width: 1024px)" rel="preload"/> <link as="font" crossorigin="" href="//www.lemonde.fr/bucket/assets/9b6e1d3a1d035999ff750fe3b08fe717b62420d7/fonts/marr-sans/MarrSans-Medium-Web.woff2" rel="preload" type="font/woff2"/> <link as="font" crossorigin="" href="//www.lemonde.fr/bucket/assets/9b6e1d3a1d035999ff750fe3b08fe717b62420d7/fonts/marr-sans-cond/MarrSansCondensed-Medium-Web.woff2" rel="preload" type="font/woff2"/> <link as="font" crossorigin="" href="//www.lemonde.fr/bucket/assets/9b6e1d3a1d035999ff750fe3b08fe717b62420d7/fonts/variables/the-antiqua-b/TheAntiquaB-LeMonde.woff2" rel="preload" type="font/woff2"/> <link href="/manifest.json" rel="manifest"/> <script>var lmd = {"consent":{"version":1},"context":{"aec":false,"pageType":"Rubrique_Une"},"user":false,"lang":"fr","projectLangFR":true,"hosts":{"lemonde":"www.lemonde.fr","sf_secure":"secure.lemonde.fr","forecast":"forecast.lemonde.fr"},"env":"prd","analytics":{"oneNext":{"id":"244044216595"},"fba":{"id":"122349388153507","idCommunication":"607705069438811"},"amplitude":{"id":"7dec6d6e90d5288af6e9a882f8def199","arvatoSelectionCode":"false"},"chartbeat":{"domain":"lemonde.fr"},"smart_tag":{"url":"https:\/\/www.lemonde.fr\/bucket\/assets\/9b6e1d3a1d035999ff750fe3b08fe717b62420d7\/js\/9b6e1d3a1d035999ff750fe3b08fe717b62420d7.__site_id__.js","pixelPath":"\/9b6e1d3a1d035999ff750fe3b08fe717b62420d7","customObject":{"Pagetype":"Home","Population":"Gratuit","Producteur":"Edito"},"level2":5,"chapter1":"Home","chapter2":"Beta","chapter3":"evenementielle","na ...
# lmd.device = "desktop";
# </script> <script type="text/javascript">!function(){"use strict";var e;(function(e){e.exports=function(){for(var e,t="__tcfapiLocator",a=[],r=window;r;){try{if(r.frames[t]){e=r;break}}catch(e){}if(r===window.top)break;r=r.parent}e||(function e(){var a=r.document,n=!!r.frames[t];if(!n)if(a.body){var s=a.createElement("iframe");s.style.cssText="display:none",s.name=t,a.body.appendChild(s)}else setTimeout(e,5);return!n}(),r.__tcfapi=function(){for(var e,t=arguments.length,r=new Array(t),n=0;n<t;n++)r[n]=arguments[n];if(!r.length)return a;if("setGdprApplies"===r[0])r.length>3&&2===parseInt(r[1],10)&&"boolean"==typeof r[3]&&(e=r[3],"function"==typeof r[2]&&r[2]("set",!0));else if("ping"===r[0]){var s={gdprApplies:e,cmpLoaded:!1,cmpStatus:"stub"};"function"==typeof r[2]&&r[2](s)}else a.push(r)},r.addEventListener("message",(function(e){var t="string"==typeof e.data,a={};try{a=t?JSON.parse(e.data):e.data}catch(e){}var r=a.__tcfapiCall;r&&window.__tcfapi(r.command,r.version,(function(a,n){var s={__tcfapiReturn:{returnValue:a,success:n,callId:r.callId}};t&&(s=JSON.stringify(s)),e&&e.source&&e.source.postMessage&&e.source.postMessage(s,"*")}),r.parameter)}),!1))}}(e={exports:{}},e.exports),e.exports)()}();</script> <script type="text/javascript">var GDPR_CONFIG = {"displayMode":"standard","usePiano":true};</script> <script async="1" src="//cmp.lemonde.fr/js/lemonde.min.js" type="text/javascript"></script> <script>
#                 if(typeof Promise === 'undefined' || (sessionStorage.fontsFirst && sessionStorage.fontsLast && 'fonts' in document)) {
#                     document.documentElement.classList.add('fonts-loaded');
#                 }
#             </script> <style type="text/css">@font-face{font-family:"The Antiqua B";src:url("/bucket/assets/9b6e1d3a1d035999ff750fe3b08fe717b62420d7/fonts/variables/the-antiqua-b/TheAntiquaB-LeMonde.woff2") format("woff2-variations"),url("/bucket/assets/9b6e1d3a1d035999ff750fe3b08fe717b62420d7/fonts/variables/the-antiqua-b/TheAntiquaB-LeMonde.woff2") format("woff2");font-display:swap;font-style:normal;font-weight:100 900;font-stretch:25% 150%}@font-face{font-family:"The Antiqua B standard";src:url("/bucket/assets/9b6e1d3a1d035999ff750fe3b08fe717b62420d7/fonts/the-antiqua-b/TheAntiquaB_LT_800.eot");src:local("TheAntiquaB_LT_800"),url("/bucket/assets/9b6e1d3a1d035999ff750fe3b08fe717b62420d7/fonts/the-antiqua-b/TheAntiquaB_LT_800.eot?#iefix") format("embedded-opentype"),url("/bucket/assets/9b6e1d3a1d035999ff750fe3b08fe717b62420d7/fonts/the-antiqua-b/TheAntiquaB_LT_800.woff2") format("woff2"),url("/bucket/assets/9b6e1d3a1d035999ff750fe3b08fe717b62420d7/fonts/the-antiqua-b/TheAntiquaB_LT_800.woff") format("woff"),url("/bucket/assets/9b6e1d3a1d035999ff750fe3b08fe717b62420d7/fonts/the-antiqua-b/TheAntiquaB_LT_800.svg#TheAntiquaB_LT_800") format("svg");font-display:swap;font-style:normal;font-weight:800}@font-face{font-family:"Marr Sans Condensed";src:url("/bucket/assets/9b6e1d3a1d035999ff750fe3b08fe717b62420d7/fonts/marr-sans-cond/MarrSansCondensed-Medium-Web.eot");src:url("/bucket/assets/9b6e1d3a1d035999ff750fe3b08fe717b62420d7/fonts/marr-sans-cond/MarrSansCondensed-Medium-Web.eot?#iefix") format("embedded-opentype"),url("/bucket/assets/9b6e1d3a1d035999ff750fe3b08fe717b62420d7/fonts/marr-sans-cond/MarrSansCondensed-Medium-Web.woff2") format("woff2"),url("/bucket/assets/9b6e1d3a1d035999ff750fe3b08fe717b62420d7/fonts/marr-sans-cond/MarrSansCondensed-Medium-Web.woff") format("woff");font-display:swap;font-style:normal;font-weight:500}@font-face{font-family:"Marr Sans";src:url("/bucket/assets/9b6e1d3a1d035999ff750fe3b08fe717b62420d7/fonts/marr-sans/MarrSans-Regular-Web.eot");src:url("/bucket/assets/9b6e1d3a1d035999ff750fe3b08fe717b62420d7/fonts/marr-sans/MarrSans-Regular-Web.eot?#iefix") format("embedded-opentype"),url("/bucket/assets/9b6e1d3a1d035999ff750fe3b08fe717b62420d7/fonts/marr-sans/MarrSans-Regular-Web.woff2") format("woff2"),url("/bucket/assets/9b6e1d3a1d035999ff750fe3b08fe717b62420d7/fonts/marr-sans/MarrSans-Regular-Web.woff") format("woff");font-display:swap;font-style:normal;font-weight:400}@font-face{font-family:"Marr Sans";src:url("/bucket/assets/9b6e1d3a1d035999ff750fe3b08fe717b62420d7/fonts/marr-sans/MarrSans-Medium-Web.eot");src:url("/bucket/assets/9b6e1d3a1d035999ff750fe3b08fe717b62420d7/fonts/marr-sans/MarrSans-Medium-Web.eot?#iefix") format("embedded-opentype"),url("/bucket/assets/9b6e1d3a1d035999ff750fe3b08fe717b62420d7/fonts/marr-sans/MarrSans-Medium-Web.woff2") format("woff2"),url("/bucket/assets/9b6e1d3a1d035999ff750fe3b08fe717b62420d7/fonts/marr-sans/MarrSans-Medium-Web.woff") format("woff");font-display:swap;font-style:normal;font-weight:500}.weight--hairline{font-weight:100}.weight--thin{font-weight:200}.weight--light{font-weight:300}.weight--normal{font-weight:400}.weight--medium{font-weight:500}.weight--semibold{font-weight:600}.weight--bold{font-weight:700}.weight--extrabold{font-weight:800}.weight--black{font-weight:900}[data-af-custom-fonts=af-creatives-text]{font-family:"Marr Sans",sans-serif !important}
# </style> <script>(()=>{var e={5082:e=>{!function(){function t(e,t){document.addEventListener?e.addEventListener("scroll",t,!1):e.attachEvent("scroll",t)}function n(e){this.g=document.createElement("div"),this.g.setAttribute("aria-hidden","true"),this.g.appendChild(document.createTextNode(e)),this.h=document.createElement("span"),this.i=document.createElement("span"),this.m=document.createElement("span"),this.j=document.createElement("span"),this.l=-1,this.h.style.cssText="max-width:none;display:inline-block;position:absolute;height:100%;width:100%;overflow:scroll;font-size:16px;",this.i.style.cssText="max-width:none;display:inline-block;position:absolute;height:100%;width:100%;overflow:scroll;font-size:16px;",this.j.style.cssText="max-width:none;display:inline-block;position:absolute;height:100%;width:100%;overflow:scroll;font-size:16px;",this.m.style.cssText="display:inline-block;width:200%;height:200%;font-size:16px;max-width:none;",this.h.appendChild(this.m),this.i.appendChild(this.j),this.g.appendChild(this.h),this.g.appendChild(this.i)}function i(e,t){e.g.style.cssText="max-width:none;min-width:20px;min-height:20px;display:inline-block;overflow:hidden;position:absolute;width:auto;margin:0;padding:0;top:-999px;white-space:nowrap;font-synthesis:none;font:"+t+";"}function o(e){var t=e.g.offsetWidth,n=t+100;return e.j.style.width=n+"px",e.i.scrollLeft=n,e.h.scrollLeft=e.h.scrollWidth+100,e.l!==t&&(e.l=t,!0)}function s(e,n){function i(){var e=s;o(e)&&null!==e.g.parentNode&&n(e.l)}var s=e;t(e.h,i),t(e.i,i),o(e)}function a(e,t,n){t=t||{},n=n||window,this.family=e,this.style=t.style||"normal",this.weight=t.weight||"normal",this.stretch=t.stretch||"normal",this.context=n}var d=null,r=null,l=null,c=null;function h(e){return null===c&&(c=!!e.document.fonts),c}function u(e,t){var n=e.style,i=e.weight;if(null===l){var o=document.createElement("div");try{o.style.font="condensed 100px sans-serif"}catch(e){}l=""!==o.style.font}return[n,i,l?e.stretch:"","100px",t].join(" ")}a.prototype.load=function(e,t){var o=this,a=e||"BESbswy",l=0,c=t||3e3,f=(new Date).getTime();return new Promise((function(e,t){if(h(o.context)&&!function(e){return null===r&&(h(e)&&/Apple/.test(window.navigator.vendor)?(e=/AppleWebKit\/([0-9]+)(?:\.([0-9]+))(?:\.([0-9]+))/.exec(window.navigator.userAgent),r=!!e&&603>parseInt(e[1],10)):r=!1),r}(o.context)){var m=new Promise((function(e,t){!function n(){(new Date).getTime()-f>=c?t(Error(c+"ms timeout exceeded")):o.context.document.fonts.load(u(o,'"'+o.family+'"'),a).then((function(t){1<=t.length?e():setTimeout(n,25)}),t)}()})),p=new Promise((function(e,t){l=setTimeout((function(){t(Error(c+"ms timeout exceeded"))}),c)}));Promise.race([p,m]).then((function(){clearTimeout(l),e(o)}),t)}else!function(e){document.body?e():document.addEventListener?document.addEventListener("DOMContentLoaded",(function t(){document.removeEventListener("DOMContentLoaded",t),e()})):document.attachEvent("onreadystatechange",(function t(){"interactive"!=document.readyState&&"complete"!=document.readyState||(document.detachEvent("onreadystatechange",t),e())}))}((function(){function r(){var t;(t=-1!=w&&-1!=g||-1!=w&&-1!=v||-1!=g&&-1!=v)&&((t=w!=g&&w!=v&&g!=v)||(null===d&&(t=/AppleWebKit\/([0-9]+)(?:\.([0-9]+))/.exec(window.navigator.userAgent),d=!!t&&(536>parseInt(t[1],10)||536===parseInt(t[1],10)&&11>=parseInt(t[2],10))),t=d&&(w==x&&g==x&&v==x||w==y&&g==y&&v==y||w==E&&g==E&&v==E)),t=!t),t&&(null!==T.parentNode&&T.parentNode.removeChild(T),clearTimeout(l),e(o))}var h=new n(a),m=new n(a),p=new n(a),w=-1,g=-1,v=-1,x=-1,y=-1,E=-1,T=document.createElement("div");T.dir="ltr",i(h,u(o,"sans-serif")),i(m,u(o,"serif")),i(p,u(o,"monospace")),T.appendChild(h.g),T.appendChild(m.g),T.appendChild(p.g),o.context.document.body.appendChild(T),x=h.g.offsetWidth,y=m.g.offsetWidth,E=p.g.offsetWidth,function e(){if((new Date).getTime()-f>=c)null!==T.parentNode&&T.parentNode.removeChild(T),t(Error(c+"ms timeout exceeded"));else{var n=o.context.document.hidden;!0!==n&&voi ...
# !function(C,O,U,R,I,E,T){
#     var q = (a) => {a = a || O; return C.createElement(a)},
#         t = (a) => {U[E] = {};U[E].a = a},
#         p = (u, e) => {
#             var a = q(), b = C.querySelector(O);
#             a.src = R + u;
#             if (e) {
#                 a.onerror = () => t(T);a.onload = () => t(!T)
#             };
#             b.parentNode.insertBefore(a, b)
#         },
#         d = () => {
#             try {
#                 if (U[E].a)  p(I + "/cidbmp/adv.js");
#                 else {
#                     if (Math.random()>0.1) return;
#                     var a = q("img");
#                     a.style = "display:none!important;";
#                     a.src = R + I + "/dbabp/noa" + E + "?clientWidth=" + U.innerWidth + "&network=mpub&sa=10";
#                     C.body.appendChild(a);
#                 }
#             } catch (e) {
#                 setTimeout(d, 100);
#             }
#         };
#     p("pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-9945624415527048", T);
#     d();
# }(document, "script", window, "https://", "storage.googleapis.com", "dblock", !0);
# </script> <script async="1" src="//www.lemonde.fr/bucket/assets/9b6e1d3a1d035999ff750fe3b08fe717b62420d7/js/vendor.bundle.js"></script>
# <script async="1" src="//www.lemonde.fr/bucket/assets/9b6e1d3a1d035999ff750fe3b08fe717b62420d7/js/batch_load.bundle.js"></script>
# <script async="" id="ebx" src="//applets.ebxcdn.com/ebx.js"></script> </head> <body id="js-body"> <div aria-hidden="true" class="dfp-slot dfp__slot dfp-unloaded" data-format="cover" id="cover"></div> <div class="old__header" id="Header"> <div class="lmi-lang-switcher"> <a class="lmi-lang-switcher__lang lmi-lang-switcher__lang--active" href="https://www.lemonde.fr">Français</a> <div class="lmi-lang-switcher__separator"></div> <a class="lmi-lang-switcher__lang js-lang-switcher" href="https://www.lemonde.fr/en/">English</a> </div> <header class="Header Header--home"> <div class="left"> <a class="Header__jelec" data-target="jelec-header" href="https://journal.lemonde.fr" id="jelec_link" rel="noopener" style=" background-image: url('/thumbnail/journal/20231010/276/201?5656394');" target="_blank"> <p>Consulter<br/>le journal</p> </a> <button class="Burger js-nav-burger" id="Burger-mobile"> <span class="Burger__icon"> <span class="sr-only">Navigation</span> </span> </button> </div> <div class="center center--home"> <div class="Header__logo"> <a href="/"> <div class="logo__lemonde logo--full"></div> <span class="sr-only">Le Monde - retour à la une</span> </a> </div> </div> <div class="right"> <div class="Header__actions Header__actions--desktop old__header-actions-right"> <a class="Header__connexion js-header-login Header__connexion--hide js-header-login-staled" href="https://secure.lemonde.fr/sfuser/connexion"> <span class="icon__nav-connexion"> <span class="sr-only">Se connecter</span> </span> <span class="login-info">Se connecter</span> </a> <a class="lmd-btn lmd-btn--s lmd-btn--premium js-btn-premium" href="https://abo.lemonde.fr/?lmd_medium=BOUTONS_LMFR&amp;lmd_campaign=CTA_LMFR&amp;lmd_position=HEADER&amp;lmd_sequence=5&amp;lmd_type_de_page=Home" rel="nofollow">S’abonner<span class="lmd-u-hide-mobile lmd-u-hide-sticky"> dès 5,49 €/mois</span></a> </div> </div> </header> </div> <div class="Header__nav-container"> <nav class="Nav Nav--square Nav--free" data-is-home="1" data-sticky="0" id="Nav"> <div class="wrapper" id="nav-desktop"> <ul class="" id="nav-markup"> <li class="Nav__item js-burger-to-show Nav__item--hide"> </li> <li class="Nav__item Nav__item-home Nav__item--extended Nav__item--active"> <a class="Burger__right-arrow js-home-tab" data-target="a-la-une" href="/"> <span class="icon__home"></span> <span class="js-burger-to-show">À la une</span> <span class="sr-only">nav_back_to_home</span> </a> </li> <li class="Nav__item Nav__item-en-continu"> <a class="Burger__right-arrow js-home-tab" data-lazyload="0" data-target="en-continu" href="/" id="js-home-tab-continu" role="button"> <span class="icon__nav-en-continu"></span> <span class="js-burger-to-show">En continu</span> </a> </li> <li class="lmi-mobile-lang-switcher"> <div class="lmi-mobile-lang-switcher__title">Choisir une édition</div> <a class="lmi-mobile-lang-switcher__lang lmi-mobile-lang-switcher__lang--active" href="https://www.lemonde.fr"> <div class="lmi-mobile-lang-switcher__checkbox"></div> Français </a> <a class="lmi-mobile-lang-switcher__lang" href="https://www.lemonde.fr/en/"> <div class="lmi-mobile-lang-switcher__checkbox"></div> English </a> </li> <li class="Nav__item Nav__item--droppable Nav__item-actualites"> <a aria-expanded="false" class="Nav__item-link js-dropdown Burger__right-arrow" data-target="actualite" href="#" role="button">Actualités</a> <div class="Nav__sub-item js-burger-open Nav__sub-item-actualites" data-height="0"> <div class="wrapper"> <div class="Nav__container Nav__container--left"> <span>En ce moment</span> <ul> <li> <a class="js-actu-tag" data-suggestion="" href="/attaque-du-hamas-contre-israel/">Attaque du Hamas contre Israël</a> </li> <li> <a class="js-actu-tag" data-suggestion="" href="/crise-ukrainienne/">Guerre en Ukraine</a> </li> <li> <a class="js-actu-tag" data-suggestion="" href="/climat/">Climat</a> </li> <li> <a class="js-actu-tag" data-suggestion="" href="/coupe-du-monde-rugby/">Coupe du monde de rugby 2023</a> </li> <li> <a  ...
#   "@context": "https://schema.org",
#   "@type": "NewsMediaOrganization",
#   "name": "Le Monde",
#   "url": "https://www.lemonde.fr",
#   "logo": "https://asset.lemde.fr/medias/img/social-network/default.png",
#   "sameAs": [
#     "https://www.facebook.com/lemonde.fr",
#     "https://twitter.com/lemondefr",
#     "https://www.instagram.com/lemondefr/",
#     "https://www.youtube.com/user/LeMonde",
#     "https://www.linkedin.com/company/le-monde/"
#   ]
# }
# </script> <script async="1" src="//www.lemonde.fr/bucket/assets/9b6e1d3a1d035999ff750fe3b08fe717b62420d7/js/common.bundle.js"></script>
# <script async="1" src="//www.lemonde.fr/bucket/assets/9b6e1d3a1d035999ff750fe3b08fe717b62420d7/js/home.bundle.js"></script>
# <div class="overlay" id="overlay"></div> <script async="1" data-gdpr-no-consent-src="https://widgets.outbrain.com/outbrain.js?i=fabb77af" data-gdpr-purposes="ads" data-gdpr-src="https://widgets.outbrain.com/outbrain.js?i=fabb77af" type="text/plain"></script> <script async="1" data-gdpr-purposes="ads" data-gdpr-src="//www.lemonde.fr/bucket/assets/9b6e1d3a1d035999ff750fe3b08fe717b62420d7/js/ads.bundle.js" type="text/plain"></script> <script async="1" src="/bucket/assets/9b6e1d3a1d035999ff750fe3b08fe717b62420d7/js/9b6e1d3a1d035999ff750fe3b08fe717b62420d7.bundle.js"></script>
# <script async="1" data-gdpr-purposes="analytics" data-gdpr-src="//www.lemonde.fr/bucket/assets/9b6e1d3a1d035999ff750fe3b08fe717b62420d7/js/anltcs.bundle.js" type="text/plain"></script> <script async="1" src="//www.lemonde.fr/bucket/assets/9b6e1d3a1d035999ff750fe3b08fe717b62420d7/js/forecast.bundle.js"></script>
# <script async="1" data-gdpr-purposes="personalization" data-gdpr-src="//www.lemonde.fr/bucket/assets/9b6e1d3a1d035999ff750fe3b08fe717b62420d7/js/survey.bundle.js" type="text/plain"></script> <script async="1" data-gdpr-purposes="personalization" data-gdpr-src="//www.lemonde.fr/bucket/assets/9b6e1d3a1d035999ff750fe3b08fe717b62420d7/js/perso.bundle.js" type="text/plain"></script> <script async="1" data-gdpr-purposes="social" data-gdpr-src="//www.lemonde.fr/bucket/assets/9b6e1d3a1d035999ff750fe3b08fe717b62420d7/js/scls.bundle.js" type="text/plain"></script> <script async="1" data-gdpr-purposes="analytics" data-gdpr-src="https://news.google.com/swg/js/v1/swg.js" subscriptions-control="manual" type="text/plain"></script> <script async="1" data-gdpr-purposes="personalization" data-gdpr-src="//www.lemonde.fr/bucket/assets/9b6e1d3a1d035999ff750fe3b08fe717b62420d7/js/batch_push.bundle.js" type="text/plain"></script> <script>var ADS_CONFIG = {"adUnit":"\/128139881\/LM_lemonde\/a_la_une\/a_la_une\/hp","targets":{"keywords":"a_la_une","rub":"a_la_une","rubriques":[]}}</script> <script async="1" data-gdpr-no-consent-src="https://wrapper.lemde.fr/v2/glmaw.js" data-gdpr-purposes="ads" data-gdpr-src="https://wrapper.lemde.fr/v2/glmaw.js" type="text/plain"></script> </body> </html>

# %% [markdown]
# Lets Parse the Netherlands site

# %%
result = requests.get(country_newspapers['Netherlands'])
soup = bs4.BeautifulSoup(result.text, 'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="de" prefix="content: http://purl.org/rss/1.0/modules/content/  dc: http://purl.org/dc/terms/  foaf: http://xmlns.com/foaf/0.1/  og: http://ogp.me/ns#  rdfs: http://www.w3.org/2000/01/rdf-schema#  schema: http://schema.org/  sioc: http://rdfs.org/sioc/ns#  sioct: http://rdfs.org/sioc/types#  skos: http://www.w3.org/2004/02/skos/core#  xsd: http://www.w3.org/2001/XMLSchema# ">
# <head>
# <meta charset="utf-8"/>
# <style>/* @see https://github.com/aFarkas/lazysizes#broken-image-symbol */.js img.lazyload:not([src]) { visibility: hidden; }/* @see https://github.com/aFarkas/lazysizes#automatically-setting-the-sizes-attribute */.js img.lazyloaded[data-sizes=auto] { display: block; width: 100%; }</style>
# <meta content="index, follow" name="robots"/>
# <meta content="Deutschland verstehen: deutschland.de erklärt Deutschlands Politik ✓, Wirtschaft ✓, Gesellschaft ✓, Kultur ✓ und globale Partnerschaften ✓. Aktuell, übersichtlich und verständlich. ►" name="description"/>
# <meta content="31292782350" property="fb:pages"/>
# <meta content="625047324193344" property="fb:app_id"/>
# <meta content="website" property="og:type"/>
# <meta content="deutschland.de - Euer Link zu Deutschland" property="og:title"/>
# <meta content="Deutschland verstehen: deutschland.de erklärt Deutschlands Politik ✓ Wirtschaft ✓ Gesellschaft ✓ Kultur ✓ und globale Partnerschaften ✓ in spannenden Reportagen, kurzen Fakten, interaktiven Formaten und Interviews. Aktuell, übersichtlich und verständlich." property="og:description"/>
# <meta content="https://www.deutschland.de/sites/default/files/styles/crop_story_content/public/media/image/deutschland-de-website-facebook_banner.jpg" property="og:image"/>
# <meta content="https://www.deutschland.de/sites/default/files/styles/crop_story_content/public/media/image/deutschland-de-website-facebook_banner.jpg" property="og:image:url"/>
# <meta content="https://www.facebook.com/deutschland.de" property="article:publisher"/>
# <meta content="Deutschland verstehen: deutschland.de erklärt Deutschlands Politik ✓ Wirtschaft ✓ Gesellschaft ✓ Kultur ✓ und globale Partnerschaften ✓ in spannenden Reportagen, kurzen Fakten und Interviews. Aktuell, übersichtlich und verständlich. ►" name="twitter:description"/>
# <meta content="deutschland.de - Euer Link zu Deutschland" name="twitter:title"/>
# <meta content="Drupal 9 (https://www.drupal.org)" name="Generator"/>
# <meta content="width" name="MobileOptimized"/>
# <meta content="true" name="HandheldFriendly"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="https://www.deutschland.de/de" hreflang="de" rel="alternate"/>
# <link href="https://www.deutschland.de/en" hreflang="en" rel="alternate"/>
# <link href="https://www.deutschland.de/fr" hreflang="fr" rel="alternate"/>
# <link href="https://www.deutschland.de/es" hreflang="es" rel="alternate"/>
# <link href="https://www.deutschland.de/pt-br" hreflang="pt-br" rel="alternate"/>
# <link href="https://www.deutschland.de/pl" hreflang="pl" rel="alternate"/>
# <link href="https://www.deutschland.de/tr" hreflang="tr" rel="alternate"/>
# <link href="https://www.deutschland.de/ru" hreflang="ru" rel="alternate"/>
# <link href="https://www.deutschland.de/zh-hans" hreflang="zh-hans" rel="alternate"/>
# <link href="https://www.deutschland.de/ar" hreflang="ar" rel="alternate"/>
# <link href="https://www.deutschland.de/de" rel="canonical"/>
# <link href="https://www.deutschland.de/de/node/4" rel="shortlink"/>
# <title>deutschland.de - Euer Link zu Deutschland</title>
# <link href="/sites/default/files/css/css_cNu06Cf38cWr2FWJLbPQlT91_T-UpkIYhU-3Fut8Orw.css" media="all" rel="stylesheet"/>
# <script src="/sites/default/files/js/js_IBHB3sk_hEno-9ifomaPQN0eEfURcfGAuspAbpBXu7A.js"></script>
# <link href="/themes/custom/plattform_deutschland/static-assets/favicons/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/themes/custom/plattform_deutschland/static-assets/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/themes/custom/plattform_deutschland/static-assets/favicons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/themes/custom/plattform_deutschland/static-assets/favicons/favicon.ico" rel="shortcut icon"/>
# <link color="#5bbad5" href="/themes/custom/plattform_deutschland/static-assets/favicons/safari-pinned-tab.svg" rel="mask-icon"/>
# <meta content="/themes/custom/plattform_deutschland/static-assets/favicons/browserconfig.xml" name="msapplication-config"/>
# <meta content="#ffffff" name="theme-color"/>
# <meta content="PyK-Lp0tnut0vefu_bl61VeeR6GSosl6TRDZD6827RY" name="google-site-verification"/>
# </head>
# <body class="page" data-piwik-app-id="80438aeb-b988-4f49-b5bb-5404336057d0" data-piwik-web-id="989ac08b-cbec-4660-8de1-da3b4e13cf3e">
# <div class="dialog-off-canvas-main-canvas page" data-off-canvas-main-canvas="">
# <a class="skip-to-main" href="#main">Zum Hauptinhalt springen</a>
# <header class="header">
# <div class="header__sticky">
# <div class="header__inner">
# <div class="header__content">
# <a class="header__logo" href="/de">
# <span class="screen-reader-text">Zur Startseite wechseln</span>
# </a>
# <div class="header__navigation-wrapper">
# <nav aria-label="Hauptmenü" class="main-navigation">
# <div class="main-navigation__scroll">
# <ul class="main-navigation__items">
# <li class="main-navigation__item">
# <a class="main-navigation__link" href="/de/news">News</a>
# </li>
# <li class="main-navigation__item">
# <a class="main-navigation__link" href="/de/topic/politik">Politik</a>
# </li>
# <li class="main-navigation__item">
# <a class="main-navigation__link" href="/de/topic/leben">Leben</a>
# </li>
# <li class="main-navigation__item">
# <a class="main-navigation__link" href="/de/topic/wissen">Wissen</a>
# </li>
# <li class="main-navigation__item">
# <a class="main-navigation__link" href="/de/topic/wirtschaft">Wirtschaft</a>
# </li>
# <li class="main-navigation__item">
# <a class="main-navigation__link" href="/de/topic/kultur">Kultur</a>
# </li>
# <li class="main-navigation__item">
# <a class="main-navigation__link" href="/de/topic/umwelt">Umwelt</a>
# </li>
# <li class="main-navigation__item">
# <a class="main-navigation__link" href="/de/arbeiten-in-deutschland">Arbeiten</a>
# </li>
# <li class="main-navigation__item">
# <a class="main-navigation__link" href="/de/studieren-in-deutschland">Studieren</a>
# </li>
# <li class="main-navigation__item">
# <a class="main-navigation__link" href="/de/deutschland-auf-einen-blick">Auf einen Blick</a>
# </li>
# <li class="main-navigation__item">
# <a class="main-navigation__link" href="/de/videos">Videos</a>
# </li>
# </ul>
# </div>
# </nav>
# </div>
# <div class="header__buttons">
# <a class="header__signLanguageButton" href="https://www.deutschland.de/de/videoseite-deutschlandde-in-gebaerdensprache">
# <span class="screen-reader-text">International sign language</span>
# </a>
# <a class="header__searchButton" href="/de/search">
# <span class="screen-reader-text">Zur Suche wechseln</span>
# </a>
# <a class="header__languageButton" href="#">
# <span class="screen-reader-text">Sprachmenü öffnen</span>
# </a>
# <a class="header__menuButton" href="#">
# <span class="screen-reader-text">Metamenü öffnen</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </header>
# <div class="sidebar">
# <div class="sidebar__backdrop"></div>
# <div class="sidebar__inner">
# <a class="sidebar__closeButton" href="#">
# <span class="sidebar__close">
# <span class="screen-reader-text">Sprachmenü schließen</span>
# </span>
# </a>
# <div class="sidebar__content">
# <nav aria-label="Sprachmenü" class="language-menu">
# <ul class="language-menu__items">
# <li class="language-menu__item" lang="de">
# <a aria-current="page" class="language-menu__link language-menu__link--current" href="/de" tabindex="-1">
# <span class="language-menu__label">Deutsch</span>
# </a>
# </li>
# <li class="language-menu__item" lang="en">
# <a class="language-menu__link" href="/en">
# <span class="language-menu__label">English</span>
# </a>
# </li>
# <li class="language-menu__item" lang="fr">
# <a class="language-menu__link" href="/fr">
# <span class="language-menu__label">Français</span>
# </a>
# </li>
# <li class="language-menu__item" lang="es">
# <a class="language-menu__link" href="/es">
# <span class="language-menu__label">Español</span>
# </a>
# </li>
# <li class="language-menu__item" lang="pt-br">
# <a class="language-menu__link" href="/pt-br">
# <span class="language-menu__label">Português, Brasil</span>
# </a>
# </li>
# <li class="language-menu__item" lang="pl">
# <a class="language-menu__link" href="/pl">
# <span class="language-menu__label">Polski</span>
# </a>
# </li>
# <li class="language-menu__item" lang="tr">
# <a class="language-menu__link" href="/tr">
# <span class="language-menu__label">Türkçe</span>
# </a>
# </li>
# <li class="language-menu__item" lang="ru">
# <a class="language-menu__link" href="/ru">
# <span class="language-menu__label">Русский</span>
# </a>
# </li>
# <li class="language-menu__item" lang="zh-hans">
# <a class="language-menu__link" href="/zh-hans">
# <span class="language-menu__label">中文</span>
# </a>
# </li>
# <li class="language-menu__item" lang="ar">
# <a class="language-menu__link" href="/ar">
# <span class="language-menu__label">العربية</span>
# </a>
# </li>
# </ul>
# </nav>
# </div>
# </div>
# </div>
# <div class="sidebar">
# <div class="sidebar__backdrop"></div>
# <div class="sidebar__inner">
# <a class="sidebar__closeButton" href="#">
# <span class="sidebar__close">
# <span class="screen-reader-text">Metamenü schließen</span>
# </span>
# </a>
# <div class="sidebar__content">
# <nav aria-label="Metamenü" class="burger-menu">
# <ul class="burger-menu__items">
# <li class="burger-menu__item">
# <a class="burger-menu__link" href="/de/topic/politik">
# <span class="burger-menu__label">Politik</span>
# </a>
# </li>
# <li class="burger-menu__item">
# <a class="burger-menu__link" href="/de/topic/leben">
# <span class="burger-menu__label">Leben</span>
# </a>
# </li>
# <li class="burger-menu__item">
# <a class="burger-menu__link" href="/de/topic/wissen">
# <span class="burger-menu__label">Wissen</span>
# </a>
# </li>
# <li class="burger-menu__item">
# <a class="burger-menu__link" href="/de/topic/wirtschaft">
# <span class="burger-menu__label">Wirtschaft</span>
# </a>
# </li>
# <li class="burger-menu__item">
# <a class="burger-menu__link" href="/de/topic/kultur">
# <span class="burger-menu__label">Kultur</span>
# </a>
# </li>
# <li class="burger-menu__item">
# <a class="burger-menu__link" href="/de/topic/umwelt">
# <span class="burger-menu__label">Umwelt</span>
# </a>
# </li>
# <li class="burger-menu__item">
# <a class="burger-menu__link burger-menu__link--forward" data-function="sub-items" href="#">Regionen</a>
# <div class="burger-menu__sub-content">
# <a class="burger-menu__link burger-menu__link--backward" data-function="back" href="#">Regionen</a>
# <ul class="burger-menu__sub-items">
# <li class="burger-menu__item">
# <a class="burger-menu__link" href="/de/region/afrika">
# <span class="burger-menu__label">Afrika</span>
# </a>
# </li>
# <li class="burger-menu__item">
# <a class="burger-menu__link" href="/de/region/arabische-welt">
# <span class="burger-menu__label">Arabische Welt</span>
# </a>
# </li>
# <li class="burger-menu__item">
# <a class="burger-menu__link" href="/de/region/asien-und-pazifik">
# <span class="burger-menu__label">Asien</span>
# </a>
# </li>
# <li class="burger-menu__item">
# <a class="burger-menu__link" href="/de/region/china">
# <span class="burger-menu__label">China</span>
# </a>
# </li>
# <li class="burger-menu__item">
# <a class="burger-menu__link" href="/de/region/europa">
# <span class="burger-menu__label">Europa</span>
# </a>
# </li>
# <li class="burger-menu__item">
# <a class="burger-menu__link" href="/de/region/russland">
# <span class="burger-menu__label">Russisch</span>
# </a>
# </li>
# <li class="burger-menu__item">
# <a class="burger-menu__link" href="/de/region/israel">
# <span class="burger-menu__label">Israel</span>
# </a>
# </li>
# <li class="burger-menu__item">
# <a class="burger-menu__link" href="/de/region/lateinamerika">
# <span class="burger-menu__label">Lateinamerika</span>
# </a>
# </li>
# <li class="burger-menu__item">
# <a class="burger-menu__link" href="/de/region/nordamerika">
# <span class="burger-menu__label">Nordamerika</span>
# </a>
# </li>
# <li class="burger-menu__item">
# <a class="burger-menu__link" href="/de/region/polen">
# <span class="burger-menu__label">Polen</span>
# </a>
# </li>
# <li class="burger-menu__item">
# <a class="burger-menu__link" href="/de/region/tuerkei">
# <span class="burger-menu__label">Türkei</span>
# </a>
# </li>
# </ul>
# </div>
# </li>
# <li class="burger-menu__item">
# <a class="burger-menu__link burger-menu__link--forward" data-function="sub-items" href="#">Social-Media-Kanäle</a>
# <div class="burger-menu__sub-content">
# <a class="burger-menu__link burger-menu__link--backward" data-function="back" href="#">Social-Media-Kanäle</a>
# <ul class="burger-menu__sub-items">
# <li class="burger-menu__item">
# <a class="burger-menu__link burger-menu__link--external burger-menu__link--icon-twitter" href="https://twitter.com/de_deutschland?lang=en" rel="noopener" target="_blank">
# <span class="burger-menu__label">X deutsch</span>
# </a>
# </li>
# <li class="burger-menu__item">
# <a class="burger-menu__link burger-menu__link--external burger-menu__link--icon-twitter" href="https://twitter.com/en_germany" rel="noopener" target="_blank">
# <span class="burger-menu__label">X News</span>
# </a>
# </li>
# <li class="burger-menu__item">
# <a class="burger-menu__link burger-menu__link--external burger-menu__link--icon-twitter" href="https://twitter.com/ger_trends" rel="noopener" target="_blank">
# <span class="burger-menu__label">X Highlights</span>
# </a>
# </li>
# <li class="burger-menu__item">
# <a class="burger-menu__link burger-menu__link--external burger-menu__link--icon-twitter" href="https://twitter.com/ger_service" rel="noopener" target="_blank">
# <span class="burger-menu__label">X Service</span>
# </a>
# </li>
# <li class="burger-menu__item">
# <a class="burger-menu__link burger-menu__link--external burger-menu__link--icon-facebook" href="https://www.facebook.com/deutschland.de" rel="noopener" target="_blank">
# <span class="burger-menu__label">Facebook</span>
# </a>
# </li>
# <li class="burger-menu__item">
# <a class="burger-menu__link burger-menu__link--external burger-menu__link--icon-instagram" href="https://www.instagram.com/deutschland_de/" rel="noopener" target="_blank">
# <span class="burger-menu__label">Instagram English</span>
# </a>
# </li>
# <li class="burger-menu__item">
# <a class="burger-menu__link burger-menu__link--external burger-menu__link--icon-instagram" href="https://www.instagram.com/deutschland_ru/" rel="noopener" target="_blank">
# <span class="burger-menu__label">Instagram Russian</span>
# </a>
# </li>
# <li class="burger-menu__item">
# <a class="burger-menu__link burger-menu__link--external burger-menu__link--icon-telegram" href="https://t.me/global_deutschland_de" rel="noopener" target="_blank">
# <span class="burger-menu__label">Telegram</span>
# </a>
# </li>
# <li class="burger-menu__item">
# <a class="burger-menu__link burger-menu__link--external burger-menu__link--icon-youtube" href="https://www.youtube.com/channel/UCvOQwFjV0T8UsTDVGUOM7Gg" rel="noopener" target="_blank">
# <span class="burger-menu__label">YouTube</span>
# </a>
# </li>
# <li class="burger-menu__item">
# <a class="burger-menu__link burger-menu__link--external burger-menu__link--icon-weibo" href="https://weibo.com/deutschland0049" rel="noopener" target="_blank">
# <span class="burger-menu__label">Weibo</span>
# </a>
# </li>
# </ul>
# </div>
# </li>
# <li class="burger-menu__item">
# <a class="burger-menu__link burger-menu__link--forward" data-function="sub-items" href="#">Partnerangebote</a>
# <div class="burger-menu__sub-content">
# <a class="burger-menu__link burger-menu__link--backward" data-function="back" href="#">Partnerangebote</a>
# <ul class="burger-menu__sub-items">
# <li class="burger-menu__item">
# <a class="burger-menu__link burger-menu__link--external" href="https://www.tatsachen-ueber-deutschland.de/de" rel="noopener" target="_blank">
# <span class="burger-menu__label">Tatsachen über Deutschland</span>
# </a>
# </li>
# <li class="burger-menu__item">
# <a class="burger-menu__link burger-menu__link--external" href="https://www.goethe.de/en/index.html" rel="noopener" target="_blank">
# <span class="burger-menu__label">Goethe Institut</span>
# </a>
# </li>
# <li class="burger-menu__item">
# <a class="burger-menu__link burger-menu__link--external" href="https://www.dw.com/en/top-stories/s-9097" rel="noopener" target="_blank">
# <span class="burger-menu__label">Deutsche Welle</span>
# </a>
# </li>
# <li class="burger-menu__item">
# <a class="burger-menu__link burger-menu__link--external" href="https://land-der-ideen.de/" rel="noopener" target="_blank">
# <span class="burger-menu__label">Land der Ideen</span>
# </a>
# </li>
# <li class="burger-menu__item">
# <a class="burger-menu__link burger-menu__link--external" href="https://germanyworks.com/" rel="noopener" target="_blank">
# <span class="burger-menu__label">Germany Works.</span>
# </a>
# </li>
# <li class="burger-menu__item">
# <a class="burger-menu__link burger-menu__link--external" href="https://www.ifa.de/" rel="noopener" target="_blank">
# <span class="burger-menu__label">ifa</span>
# </a>
# </li>
# <li class="burger-menu__item">
# <a class="burger-menu__link burger-menu__link--external" href="https://www.daad.de/de/" rel="noopener" target="_blank">
# <span class="burger-menu__label">DAAD</span>
# </a>
# </li>
# <li class="burger-menu__item">
# <a class="burger-menu__link burger-menu__link--external" href="https://www.alumniportal-deutschland.org/de/" rel="noopener" target="_blank">
# <span class="burger-menu__label">Alumniportal Deutschland</span>
# </a>
# </li>
# <li class="burger-menu__item">
# <a class="burger-menu__link burger-menu__link--external" href="https://www.dandc.eu/de" rel="noopener" target="_blank">
# <span class="burger-menu__label">E+Z</span>
# </a>
# </li>
# </ul>
# </div>
# </li>
# <li class="burger-menu__item">
# <a class="burger-menu__link" href="/de/app">
# <span class="burger-menu__label">deutschland.de App</span>
# </a>
# </li>
# <li class="burger-menu__item">
# <a class="burger-menu__link" data-function="cookie_banner" href="#">
# <span class="burger-menu__label">Cookie-Einstellungen</span>
# </a>
# </li>
# <li class="burger-menu__item">
# <a class="burger-menu__link" href="/de/impressum">
# <span class="burger-menu__label">Impressum</span>
# </a>
# </li>
# <li class="burger-menu__item">
# <div class="toggle toggle--block">
# <label class="toggle__labelWrapper">
# <span class="toggle__label">Dark-Modus</span>
# <input class="toggle__input" name="is-dark-mode" type="checkbox" value="1"/>
# <span class="toggle__element"></span>
# </label>
# </div>
# </li>
# <li class="burger-menu__item">
# <div class="toggle toggle--block">
# <label class="toggle__labelWrapper">
# <span class="toggle__label">Text vergrößern</span>
# <input class="toggle__input" name="is-enlarged-text" type="checkbox" value="1"/>
# <span class="toggle__element"></span>
# </label>
# </div>
# </li>
# </ul>
# </nav>
# </div>
# </div>
# </div>
# <main class="components" id="main">
# <div class="component component--two-third component--pull-to-header-on-small" id="46856">
# <div class="component__inner">
# <div class="animated-topic-stage">
# <div class="gallery">
# <div class="gallery__slider">
# <div class="gallery__items">
# <div class="animated-topic-teaser animated-topic-teaser--auto-height">
# <a class="animated-topic-teaser__content" href="/de/topic/leben/interkulturelle-therapie-hilfe-bei-psychischen-erkrankungen">
# <div class="animated-topic-teaser__image-wrapper">
# <picture>
# <source height="640" media="all and (min-width: 1024px)" srcset="/sites/default/files/styles/animated_topic_stage/public/media/image/tdt_09102023_mentale_gesundheiti_nterkulturelle_therapie_herkunft.jpg?h=957026db&amp;itok=ackSoNmB 1x" type="image/jpeg" width="800"/>
# <source height="1333" media="all and (max-width: 767.98px) and (min-width: 576px)" srcset="/sites/default/files/styles/animated_topic_stage_mobile/public/media/image/tdt_09102023_mentale_gesundheiti_nterkulturelle_therapie_herkunft.jpg?h=96daf5ce&amp;itok=SUvBq6gQ 1x" type="image/jpeg" width="850"/>
# <source height="845" media="all and (max-width: 575.98px)" srcset="/sites/default/files/styles/animated_topic_stage_mobile_small/public/media/image/tdt_09102023_mentale_gesundheiti_nterkulturelle_therapie_herkunft.jpg?h=96daf5ce&amp;itok=GWo4UI7L 1x" type="image/jpeg" width="634"/>
# <source height="844" media="all and (min-width: 768px)" srcset="/sites/default/files/styles/animated_topic_stage_tablet/public/media/image/tdt_09102023_mentale_gesundheiti_nterkulturelle_therapie_herkunft.jpg?h=957026db&amp;itok=dhd-4rec 1x" type="image/jpeg" width="1055"/>
# <img alt="Vielen fällt es leichter, sich einem Therapeuten mit ähnlicher Herkunft zu öffnen. " src="/sites/default/files/styles/animated_topic_stage_mobile/public/media/image/tdt_09102023_mentale_gesundheiti_nterkulturelle_therapie_herkunft.jpg?h=96daf5ce&amp;itok=SUvBq6gQ" title="Vielen fällt es leichter, sich einem Therapeuten mit ähnlicher Herkunft zu öffnen. " typeof="foaf:Image"/>
# </picture>
# </div>
# <span class="animated-topic-teaser__label-wrapper">
# <span class="label">
# 	Flucht und Trauma
# </span>
# </span>
# <div class="animated-topic-teaser__headline">Interkulturelle Therapie </div>
# </a>
# </div>
# <div class="animated-topic-teaser animated-topic-teaser--auto-height">
# <a class="animated-topic-teaser__content" href="/de/topic/leben/mentale-gesundheit-hilfe-fuer-gefluechtete-refugeeum">
# <div class="animated-topic-teaser__image-wrapper">
# <picture>
# <source height="640" media="all and (min-width: 1024px)" srcset="/sites/default/files/styles/animated_topic_stage/public/media/image/tdt_10102023_mentale_gesundheit_int_ttauma_und_flucht_refugeeum.jpg?itok=r3YCLNAW 1x" type="image/jpeg" width="800"/>
# <source height="1333" media="all and (max-width: 767.98px) and (min-width: 576px)" srcset="/sites/default/files/styles/animated_topic_stage_mobile/public/media/image/tdt_10102023_mentale_gesundheit_int_ttauma_und_flucht_refugeeum.jpg?h=a9d743ff&amp;itok=49AwJrtX 1x" type="image/jpeg" width="850"/>
# <source height="845" media="all and (max-width: 575.98px)" srcset="/sites/default/files/styles/animated_topic_stage_mobile_small/public/media/image/tdt_10102023_mentale_gesundheit_int_ttauma_und_flucht_refugeeum.jpg?h=a9d743ff&amp;itok=qcTyWaHv 1x" type="image/jpeg" width="634"/>
# <source height="844" media="all and (min-width: 768px)" srcset="/sites/default/files/styles/animated_topic_stage_tablet/public/media/image/tdt_10102023_mentale_gesundheit_int_ttauma_und_flucht_refugeeum.jpg?itok=Ms0jdu2d 1x" type="image/jpeg" width="1055"/>
# <img alt="REFUGEEUM bietet online Informationen zu mentaler Gesundheit. " src="/sites/default/files/styles/animated_topic_stage_mobile/public/media/image/tdt_10102023_mentale_gesundheit_int_ttauma_und_flucht_refugeeum.jpg?h=a9d743ff&amp;itok=49AwJrtX" title="REFUGEEUM bietet online Informationen zu mentaler Gesundheit. " typeof="foaf:Image"/>
# </picture>
# </div>
# <span class="animated-topic-teaser__label-wrapper">
# <span class="label">
# 	Flucht und Trauma
# </span>
# </span>
# <div class="animated-topic-teaser__headline">Ein Instrument der Selbsthilfe </div>
# </a>
# </div>
# <div class="animated-topic-teaser animated-topic-teaser--auto-height">
# <a class="animated-topic-teaser__content" href="/de/topic/wissen/psychotherapie-wie-wird-man-psychotherapeut-in-deutschland">
# <div class="animated-topic-teaser__image-wrapper">
# <picture>
# <source height="640" media="all and (min-width: 1024px)" srcset="/sites/default/files/styles/animated_topic_stage/public/media/image/tdt_11102023_mentale_gesundheit_psychologie_studieren_psychotherapeut.jpg?h=8d85c147&amp;itok=0pSXBgNG 1x" type="image/jpeg" width="800"/>
# <source height="1333" media="all and (max-width: 767.98px) and (min-width: 576px)" srcset="/sites/default/files/styles/animated_topic_stage_mobile/public/media/image/tdt_11102023_mentale_gesundheit_psychologie_studieren_psychotherapeut.jpg?h=352b6a50&amp;itok=gW_gq7ZC 1x" type="image/jpeg" width="850"/>
# <source height="845" media="all and (max-width: 575.98px)" srcset="/sites/default/files/styles/animated_topic_stage_mobile_small/public/media/image/tdt_11102023_mentale_gesundheit_psychologie_studieren_psychotherapeut.jpg?h=352b6a50&amp;itok=WlUwHL8W 1x" type="image/jpeg" width="634"/>
# <source height="844" media="all and (min-width: 768px)" srcset="/sites/default/files/styles/animated_topic_stage_tablet/public/media/image/tdt_11102023_mentale_gesundheit_psychologie_studieren_psychotherapeut.jpg?h=8d85c147&amp;itok=zzP8nlq2 1x" type="image/jpeg" width="1055"/>
# <img alt="Die Berufsbezeichnung Psychotherapeut ist in Deutschland gesetzlich geschützt. " src="/sites/default/files/styles/animated_topic_stage_mobile/public/media/image/tdt_11102023_mentale_gesundheit_psychologie_studieren_psychotherapeut.jpg?h=352b6a50&amp;itok=gW_gq7ZC" title="Die Berufsbezeichnung Psychotherapeut ist in Deutschland gesetzlich geschützt. " typeof="foaf:Image"/>
# </picture>
# </div>
# <span class="animated-topic-teaser__label-wrapper">
# <span class="label">
# 	Mentale Gesundheit
# </span>
# </span>
# <div class="animated-topic-teaser__headline">Wie wird man Psychotherapeut? </div>
# </a>
# </div>
# <div class="animated-topic-teaser animated-topic-teaser--auto-height">
# <a class="animated-topic-teaser__content" href="/de/topic/leben/traumaforschung-hilfe-fuer-gefluechtete">
# <div class="animated-topic-teaser__image-wrapper">
# <picture>
# <source height="640" media="all and (min-width: 1024px)" srcset="/sites/default/files/styles/animated_topic_stage/public/media/image/tdt_12102023_mentale_gesundheit_traumaforschung_somalia.jpg?h=d3a7a0e2&amp;itok=VO7X9EkF 1x" type="image/jpeg" width="800"/>
# <source height="1333" media="all and (max-width: 767.98px) and (min-width: 576px)" srcset="/sites/default/files/styles/animated_topic_stage_mobile/public/media/image/tdt_12102023_mentale_gesundheit_traumaforschung_somalia.jpg?h=589f4d2c&amp;itok=oWvuYiFt 1x" type="image/jpeg" width="850"/>
# <source height="845" media="all and (max-width: 575.98px)" srcset="/sites/default/files/styles/animated_topic_stage_mobile_small/public/media/image/tdt_12102023_mentale_gesundheit_traumaforschung_somalia.jpg?h=589f4d2c&amp;itok=MBl2yHM9 1x" type="image/jpeg" width="634"/>
# <source height="844" media="all and (min-width: 768px)" srcset="/sites/default/files/styles/animated_topic_stage_tablet/public/media/image/tdt_12102023_mentale_gesundheit_traumaforschung_somalia.jpg?h=d3a7a0e2&amp;itok=334_0MAG 1x" type="image/jpeg" width="1055"/>
# <img alt="Fluchterfahrungen traumatisieren viele Menschen." src="/sites/default/files/styles/animated_topic_stage_mobile/public/media/image/tdt_12102023_mentale_gesundheit_traumaforschung_somalia.jpg?h=589f4d2c&amp;itok=oWvuYiFt" title="Fluchterfahrungen traumatisieren viele Menschen." typeof="foaf:Image"/>
# </picture>
# </div>
# <span class="animated-topic-teaser__label-wrapper">
# <span class="label">
# 	Flucht und Trauma
# </span>
# </span>
# <div class="animated-topic-teaser__headline">„Wir können Traumafolgen effektiv behandeln“ </div>
# </a>
# </div>
# <div class="animated-topic-teaser animated-topic-teaser--auto-height">
# <a class="animated-topic-teaser__content" href="/de/topic/kultur/international-rescue-committee-deutschland">
# <div class="animated-topic-teaser__image-wrapper">
# <picture>
# <source height="640" media="all and (min-width: 1024px)" srcset="/sites/default/files/styles/animated_topic_stage/public/media/image/428682700.jpg?itok=lkZmWOBN 1x" type="image/jpeg" width="800"/>
# <source height="1333" media="all and (max-width: 767.98px) and (min-width: 576px)" srcset="/sites/default/files/styles/animated_topic_stage_mobile/public/media/image/428682700.jpg?h=9926e9c6&amp;itok=yUWTYhAo 1x" type="image/jpeg" width="850"/>
# <source height="845" media="all and (max-width: 575.98px)" srcset="/sites/default/files/styles/animated_topic_stage_mobile_small/public/media/image/428682700.jpg?h=9926e9c6&amp;itok=S-EJ14wf 1x" type="image/jpeg" width="634"/>
# <source height="844" media="all and (min-width: 768px)" srcset="/sites/default/files/styles/animated_topic_stage_tablet/public/media/image/428682700.jpg?itok=RYcV_m27 1x" type="image/jpeg" width="1055"/>
# <img alt="Jobmesse in Berlin für Geflüchtete " src="/sites/default/files/styles/animated_topic_stage_mobile/public/media/image/428682700.jpg?h=9926e9c6&amp;itok=yUWTYhAo" title="Jobmesse in Berlin für Geflüchtete " typeof="foaf:Image"/>
# </picture>
# </div>
# <span class="animated-topic-teaser__label-wrapper">
# <span class="label">
# 	Flucht und Trauma
# </span>
# </span>
# <div class="animated-topic-teaser__headline">Innerlich ankommen, Arbeit finden </div>
# </a>
# </div>
# </div>
# </div>
# <div class="gallery__nav"></div>
# </div>
# </div>
# </div>
# </div>
# <div class="component component--third component--section-start" id="46857">
# <div class="component__inner">
# <div class="current-news-teaser">
# <div class="current-news-teaser__section-headline-wrapper">
# <div class="headline">
# <a class="headline__link" href="/de/news">
# <h2 class="headline__headline">Newsroom</h2>
# <span class="headline__more">
# <span class="screen-reader-text">Newsroom</span>
# </span>
# </a>
# </div>
# </div>
# <div class="row row-spacing">
# <div class="col">
# <div class="teaser-small teaser-small--always">
# <a class="teaser-small__image" href="/de/news/deutsche-aussenpolitik-news-des-tages" tabindex="-1">
# <picture>
# <source height="100" media="all and (max-width: 767.98px) and (min-width: 576px)" srcset="/sites/default/files/styles/teaser_small_always/public/media/image/09102023_428620312.jpg?itok=A60B4Zym 1x, /sites/default/files/styles/teaser_small_always_retina/public/media/image/09102023_428620312.jpg?itok=ISXofu9s 2x" type="image/jpeg" width="100"/>
# <source height="100" media="all and (max-width: 575.98px)" srcset="/sites/default/files/styles/teaser_small_always/public/media/image/09102023_428620312.jpg?itok=A60B4Zym 1x, /sites/default/files/styles/teaser_small_always_retina/public/media/image/09102023_428620312.jpg?itok=ISXofu9s 2x" type="image/jpeg" width="100"/>
# <source height="200" media="all and (min-width: 768px)" srcset="/sites/default/files/styles/teaser_small_always_retina/public/media/image/09102023_428620312.jpg?itok=ISXofu9s 2x" type="image/jpeg" width="200"/>
# <img alt="Erste deutsch-französische Kabinettsklausur in Hamburg" src="/sites/default/files/styles/teaser_small_always/public/media/image/09102023_428620312.jpg?itok=A60B4Zym" title="Erste deutsch-französische Kabinettsklausur in Hamburg" typeof="foaf:Image"/>
# </picture>
# </a>
# <a class="teaser-small__content" href="/de/news/deutsche-aussenpolitik-news-des-tages">
# <div class="teaser-small__tagline">+++ Ticker Außenpolitik +++</div>
# <div class="teaser-small__headline">Erste deutsch-französische Kabinettsklausur in Hamburg</div>
# <div class="teaser-small__summary"></div>
# </a>
# </div>
# </div>
# <div class="col">
# <div class="teaser-small teaser-small--always">
# <a class="teaser-small__image" href="/de/news/scholz-israels-sicherheit-ist-deutsche-staatsraeson" tabindex="-1">
# <picture>
# <source height="100" media="all and (max-width: 767.98px) and (min-width: 576px)" srcset="/sites/default/files/styles/teaser_small_always/public/media/image/scholz_versichert_is_79615777.jpg?itok=XPzO9J66 1x, /sites/default/files/styles/teaser_small_always_retina/public/media/image/scholz_versichert_is_79615777.jpg?itok=93Rf01qc 2x" type="image/jpeg" width="100"/>
# <source height="100" media="all and (max-width: 575.98px)" srcset="/sites/default/files/styles/teaser_small_always/public/media/image/scholz_versichert_is_79615777.jpg?itok=XPzO9J66 1x, /sites/default/files/styles/teaser_small_always_retina/public/media/image/scholz_versichert_is_79615777.jpg?itok=93Rf01qc 2x" type="image/jpeg" width="100"/>
# <source height="200" media="all and (min-width: 768px)" srcset="/sites/default/files/styles/teaser_small_always_retina/public/media/image/scholz_versichert_is_79615777.jpg?itok=93Rf01qc 2x" type="image/jpeg" width="200"/>
# <img alt="Bundeskanzler Olaf Scholz" src="/sites/default/files/styles/teaser_small_always/public/media/image/scholz_versichert_is_79615777.jpg?itok=XPzO9J66" title="Bundeskanzler Olaf Scholz" typeof="foaf:Image"/>
# </picture>
# </a>
# <a class="teaser-small__content" href="/de/news/scholz-israels-sicherheit-ist-deutsche-staatsraeson">
# <div class="teaser-small__tagline">Angriff auf Israel</div>
# <div class="teaser-small__headline">Scholz: Israels Sicherheit ist deutsche Staatsräson</div>
# <div class="teaser-small__summary"></div>
# </a>
# </div>
# </div>
# <div class="col">
# <div class="teaser-small teaser-small--always">
# <a class="teaser-small__image" href="/de/news/deutschland-stellt-sich-an-die-seite-israels" tabindex="-1">
# <picture>
# <source height="100" media="all and (max-width: 767.98px) and (min-width: 576px)" srcset="/sites/default/files/styles/teaser_small_always/public/media/image/429256048_0.jpg?h=83f49b46&amp;itok=BBeEmm2t 1x, /sites/default/files/styles/teaser_small_always_retina/public/media/image/429256048_0.jpg?h=83f49b46&amp;itok=r8uJQDwi 2x" type="image/jpeg" width="100"/>
# <source height="100" media="all and (max-width: 575.98px)" srcset="/sites/default/files/styles/teaser_small_always/public/media/image/429256048_0.jpg?h=83f49b46&amp;itok=BBeEmm2t 1x, /sites/default/files/styles/teaser_small_always_retina/public/media/image/429256048_0.jpg?h=83f49b46&amp;itok=r8uJQDwi 2x" type="image/jpeg" width="100"/>
# <source height="200" media="all and (min-width: 768px)" srcset="/sites/default/files/styles/teaser_small_always_retina/public/media/image/429256048_0.jpg?h=83f49b46&amp;itok=r8uJQDwi 2x" type="image/jpeg" width="200"/>
# <img alt="Solidarität mit Israel: Das Brandenburger Tor wird in den Farben Israels beleuchtet. " src="/sites/default/files/styles/teaser_small_always/public/media/image/429256048_0.jpg?h=83f49b46&amp;itok=BBeEmm2t" title="Solidarität mit Israel: Das Brandenburger Tor wird in den Farben Israels beleuchtet. " typeof="foaf:Image"/>
# </picture>
# </a>
# <a class="teaser-small__content" href="/de/news/deutschland-stellt-sich-an-die-seite-israels">
# <div class="teaser-small__tagline">Angriff auf Israel</div>
# <div class="teaser-small__headline">Deutschland stellt sich an die Seite Israels</div>
# <div class="teaser-small__summary"></div>
# </a>
# </div>
# </div>
# <div class="col">
# <div class="teaser-small teaser-small--always">
# <a class="teaser-small__image" href="/de/news/steinmeier-spricht-mit-us-praesident-biden" tabindex="-1">
# <picture>
# <source height="100" media="all and (max-width: 767.98px) and (min-width: 576px)" srcset="/sites/default/files/styles/teaser_small_always/public/media/image/steinmeier_zu_treffe_79600015.jpg?itok=-3WvBe6A 1x, /sites/default/files/styles/teaser_small_always_retina/public/media/image/steinmeier_zu_treffe_79600015.jpg?itok=MJLrRyF1 2x" type="image/jpeg" width="100"/>
# <source height="100" media="all and (max-width: 575.98px)" srcset="/sites/default/files/styles/teaser_small_always/public/media/image/steinmeier_zu_treffe_79600015.jpg?itok=-3WvBe6A 1x, /sites/default/files/styles/teaser_small_always_retina/public/media/image/steinmeier_zu_treffe_79600015.jpg?itok=MJLrRyF1 2x" type="image/jpeg" width="100"/>
# <source height="200" media="all and (min-width: 768px)" srcset="/sites/default/files/styles/teaser_small_always_retina/public/media/image/steinmeier_zu_treffe_79600015.jpg?itok=MJLrRyF1 2x" type="image/jpeg" width="200"/>
# <img alt="Bundespräsident Frank-Walter Steinmeier in Washington" src="/sites/default/files/styles/teaser_small_always/public/media/image/steinmeier_zu_treffe_79600015.jpg?itok=-3WvBe6A" title="Bundespräsident Frank-Walter Steinmeier in Washington" typeof="foaf:Image"/>
# </picture>
# </a>
# <a class="teaser-small__content" href="/de/news/steinmeier-spricht-mit-us-praesident-biden">
# <div class="teaser-small__tagline">Treffen in Washington</div>
# <div class="teaser-small__headline">Steinmeier spricht mit US-Präsident Biden</div>
# <div class="teaser-small__summary"></div>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="component component--section-start" id="49207">
# <div class="component__inner">
# <div class="single-link-teaser single-link-teaser--image">
# <div class="single-link-teaser__image-wrapper">
# <img alt="deutschland.de App" height="200" loading="lazy" src="/sites/default/files/styles/single_link_teaser/public/media/image/landingpage_icon_11.jpg?itok=GuPwq2hP" title="deutschland.de App" typeof="foaf:Image" width="200"/>
# </div>
# <div class="single-link-teaser__content">
# <div class="single-link-teaser__headline">Deutschland.de jetzt auch zum Hören!</div>
# <div class="single-link-teaser__summary"> Mit unserer neuen App kannst du dir unsere Artikel in deiner bevorzugten Sprache vorlesen lassen.</div>
# <div class="single-link-teaser__button">
# <a class="button button--secondary button--colorful" data-label="Jetzt kostenlos herunterladen" href="/de/app">
# 		Jetzt kostenlos herunterladen
# 	</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="component component--section-start" id="35933">
# <div class="component__inner">
# <div class="section-headline">
# <div class="headline">
# <h3 class="headline__headline">Regionen im Fokus   </h3>
# </div>
# </div>
# </div>
# </div>
# <div class="component component--third">
# <div class="component__inner">
# <div class="article-teaser-small">
# <div class="teaser-small">
# <a class="teaser-small__image" href="/de/topic/kultur/sowjetische-gedenkstaetten-in-deutschland-experte-im-interview" tabindex="-1">
# <picture>
# <source height="100" media="all and (max-width: 767.98px) and (min-width: 576px)" srcset="/sites/default/files/styles/teaser_small_always/public/media/image/dsc03015-drachenberg.jpg?itok=zU9WIIOm 1x" type="image/jpeg" width="100"/>
# <source height="100" media="all and (max-width: 575.98px)" srcset="/sites/default/files/styles/teaser_small_always/public/media/image/dsc03015-drachenberg.jpg?itok=zU9WIIOm 1x, /sites/default/files/styles/teaser_small_always_retina/public/media/image/dsc03015-drachenberg.jpg?itok=3WHv3Pfw 2x" type="image/jpeg" width="100"/>
# <source height="278" media="all and (min-width: 768px)" srcset="/sites/default/files/styles/article_teaser_small/public/media/image/dsc03015-drachenberg.jpg?itok=Ra2z8YcF 1x" type="image/jpeg" width="371"/>
# <img alt="Thomas Drachenberg ist Brandenburgischer Landeskonservator." loading="lazy" src="/sites/default/files/styles/teaser_small_always/public/media/image/dsc03015-drachenberg.jpg?itok=zU9WIIOm" title="Thomas Drachenberg ist Brandenburgischer Landeskonservator." typeof="foaf:Image"/>
# </picture>
# <span class="teaser-small__label-wrapper">
# <span class="label">
# 	Gedenkstätten
# </span>
# </span>
# </a>
# <a class="teaser-small__content" href="/de/topic/kultur/sowjetische-gedenkstaetten-in-deutschland-experte-im-interview">
# <div class="teaser-small__tagline">Russisch</div>
# <div class="teaser-small__headline">Denkmäler – Erinnerung und Ideologie</div>
# <div class="teaser-small__summary">Experte Thomas Drachenberg über den heutigen Umgang mit sowjetischen Kriegsdenkmälern in Deutschland – auch angesichts des russischen Angriffs auf die Ukraine.</div>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="component component--third">
# <div class="component__inner">
# <div class="article-teaser-small">
# <div class="teaser-small">
# <a class="teaser-small__image" href="/de/topic/wirtschaft/projekt-neue-seidenstrasse-in-duisburg-frieden-ist-wichtig" tabindex="-1">
# <picture>
# <source height="100" media="all and (max-width: 767.98px) and (min-width: 576px)" srcset="/sites/default/files/styles/teaser_small_always/public/media/image/aufmacher_297265898.jpg?itok=2jb0koUi 1x" type="image/jpeg" width="100"/>
# <source height="100" media="all and (max-width: 575.98px)" srcset="/sites/default/files/styles/teaser_small_always/public/media/image/aufmacher_297265898.jpg?itok=2jb0koUi 1x, /sites/default/files/styles/teaser_small_always_retina/public/media/image/aufmacher_297265898.jpg?itok=pttpULwx 2x" type="image/jpeg" width="100"/>
# <source height="278" media="all and (min-width: 768px)" srcset="/sites/default/files/styles/article_teaser_small/public/media/image/aufmacher_297265898.jpg?itok=L92z8sSF 1x" type="image/jpeg" width="371"/>
# <img alt="Waren auf der Schiene: Kennzeichen der Neuen Seidenstraße." loading="lazy" src="/sites/default/files/styles/teaser_small_always/public/media/image/aufmacher_297265898.jpg?itok=2jb0koUi" title="Waren auf der Schiene: Kennzeichen der Neuen Seidenstraße." typeof="foaf:Image"/>
# </picture>
# <span class="teaser-small__label-wrapper">
# <span class="label">
# 	Zehn Jahre „Neue Seidenstraße“
# </span>
# </span>
# </a>
# <a class="teaser-small__content" href="/de/topic/wirtschaft/projekt-neue-seidenstrasse-in-duisburg-frieden-ist-wichtig">
# <div class="teaser-small__tagline">China</div>
# <div class="teaser-small__headline">„Frieden ist wichtig für den Logistiksektor“</div>
# <div class="teaser-small__summary">Wie hat die „Neue Seidenstraße“ Duisburg geprägt? Ein Gespräch mit Markus Teuber, dem China-Beauftragten der Stadt, über Chancen und Herausforderungen. </div>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="component component--third">
# <div class="component__inner">
# <div class="article-teaser-small">
# <div class="teaser-small">
# <a class="teaser-small__image" href="/de/topic/leben/europaeische-medien-fuer-mehr-zusammenhalt" tabindex="-1">
# <picture>
# <source height="100" media="all and (max-width: 767.98px) and (min-width: 576px)" srcset="/sites/default/files/styles/teaser_small_always/public/media/image/bild-1_0.jpg?itok=gF2d3HIs 1x" type="image/jpeg" width="100"/>
# <source height="100" media="all and (max-width: 575.98px)" srcset="/sites/default/files/styles/teaser_small_always/public/media/image/bild-1_0.jpg?itok=gF2d3HIs 1x, /sites/default/files/styles/teaser_small_always_retina/public/media/image/bild-1_0.jpg?itok=iFWJDQKu 2x" type="image/jpeg" width="100"/>
# <source height="278" media="all and (min-width: 768px)" srcset="/sites/default/files/styles/article_teaser_small/public/media/image/bild-1_0.jpg?itok=3ThiOY9T 1x" type="image/jpeg" width="371"/>
# <img alt="Teile des ENTR-Teams bei einem „Design-Sprint“ in Polen " loading="lazy" src="/sites/default/files/styles/teaser_small_always/public/media/image/bild-1_0.jpg?itok=gF2d3HIs" title="Teile des ENTR-Teams bei einem „Design-Sprint“ in Polen " typeof="foaf:Image"/>
# </picture>
# <span class="teaser-small__label-wrapper">
# <span class="label">
# 	Medien
# </span>
# </span>
# </a>
# <a class="teaser-small__content" href="/de/topic/leben/europaeische-medien-fuer-mehr-zusammenhalt">
# <div class="teaser-small__tagline">Europa</div>
# <div class="teaser-small__headline">Europäische Medien für mehr Zusammenhalt</div>
# <div class="teaser-small__summary">Zehn Sprachen und es werden mehr: Die Deutsche Welle leitet ein multilinguales Content-Kollektiv. Die Vision von ENTR ist ein paneuropäisches Mediennetzwerk.</div>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="component component--section-start" id="24759">
# <div class="component__inner">
# <div class="link-cloud">
# <div class="link-cloud__inner">
# <h2 class="link-cloud__headline">Erfahrt mehr über Deutschland und die Welt </h2>
# <div class="link-cloud__scroll-wrapper">
# <div class="link-cloud__scroll">
# <ul class="link-cloud__items">
# <li class="link-cloud__item">
# <a class="button button--secondary button--no-wrap" data-label="Afrika" href="/de/region/afrika">
# 		Afrika
# 	</a>
# </li>
# <li class="link-cloud__item">
# <a class="button button--secondary button--no-wrap" data-label="Arabische Welt" href="/de/region/arabische-welt">
# 		Arabische Welt
# 	</a>
# </li>
# <li class="link-cloud__item">
# <a class="button button--secondary button--no-wrap" data-label="Asien und Pazifik" href="/de/region/asien-und-pazifik">
# 		Asien und Pazifik
# 	</a>
# </li>
# <li class="link-cloud__item">
# <a class="button button--secondary button--no-wrap" data-label="China" href="/de/region/china">
# 		China
# 	</a>
# </li>
# <li class="link-cloud__item">
# <a class="button button--secondary button--no-wrap" data-label="Europa" href="/de/region/europa">
# 		Europa
# 	</a>
# </li>
# <li class="link-cloud__item">
# <a class="button button--secondary button--no-wrap" data-label="Russisch" href="/de/region/russland">
# 		Russisch
# 	</a>
# </li>
# <li class="link-cloud__item">
# <a class="button button--secondary button--no-wrap" data-label="Israel" href="/de/region/israel">
# 		Israel
# 	</a>
# </li>
# <li class="link-cloud__item">
# <a class="button button--secondary button--no-wrap" data-label="Lateinamerika" href="/de/region/lateinamerika">
# 		Lateinamerika
# 	</a>
# </li>
# <li class="link-cloud__item">
# <a class="button button--secondary button--no-wrap" data-label="Nordamerika" href="/de/region/nordamerika">
# 		Nordamerika
# 	</a>
# </li>
# <li class="link-cloud__item">
# <a class="button button--secondary button--no-wrap" data-label="Polen" href="/de/region/polen">
# 		Polen
# 	</a>
# </li>
# <li class="link-cloud__item">
# <a class="button button--secondary button--no-wrap" data-label="Türkei" href="/de/region/tuerkei">
# 		Türkei
# 	</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="component component--section-start" id="50162">
# <div class="component__inner">
# <div class="article-teaser-carousel">
# <div class="article-teaser-carousel__section-headline-wrapper">
# <div class="headline">
# <h3 class="headline__headline">Internationaler Waldschutz </h3>
# </div>
# </div>
# <div class="article-teaser-carousel__carousel-wrapper">
# <div class="carousel carousel--right-edge-zero carousel--nav-bottom carousel--controls-upper carousel--controls-hover" data-item-count-max="4">
# <div class="carousel__slider">
# <div class="carousel__items">
# <div class="article-teaser">
# <a class="article-teaser__image" href="/de/topic/umwelt/wald-der-zukunft-waelder-klimaresistent-gestalten" tabindex="-1">
# <picture>
# <source height="360" media="all and (max-width: 767.98px) and (min-width: 576px)" srcset="/sites/default/files/styles/article_teaser_mobile/public/media/image/tdt_02102023_wald_wald_der_zukunft_mischwald.jpg?h=e3193a6a&amp;itok=EkAoaJXY 1x" type="image/jpeg" width="480"/>
# <source height="212" media="all and (min-width: 768px)" srcset="/sites/default/files/styles/article_teaser/public/media/image/tdt_02102023_wald_wald_der_zukunft_mischwald.jpg?h=e3193a6a&amp;itok=OA05Dr7n 1x" type="image/jpeg" width="282"/>
# <img alt="Naturnahe Mischwälder sind für den Klimawandel gewappnet. " loading="" src="/sites/default/files/styles/article_teaser_mobile/public/media/image/tdt_02102023_wald_wald_der_zukunft_mischwald.jpg?h=e3193a6a&amp;itok=EkAoaJXY" title="Naturnahe Mischwälder sind für den Klimawandel gewappnet. " typeof="foaf:Image"/>
# </picture>
# </a>
# <a class="article-teaser__content" href="/de/topic/umwelt/wald-der-zukunft-waelder-klimaresistent-gestalten">
# <div class="article-teaser__headline">Der Wald der Zukunft </div>
# <div class="article-teaser__summary">Der Wald muss sich an  Klimaerwärmung und Extremwetter anpassen. Wir erklären, wie das gelingen kann.  </div>
# </a>
# </div>
# <div class="article-teaser">
# <a class="article-teaser__image" href="/de/topic/umwelt/internationaler-waldschutz-regenwaelder-in-suedostasien-schuetzen" tabindex="-1">
# <picture>
# <source height="360" media="all and (max-width: 767.98px) and (min-width: 576px)" srcset="/sites/default/files/styles/article_teaser_mobile/public/media/image/tdt_04102023_wald_internationaler_waldschutz_susanne-gotthardt.jpg?h=7425888e&amp;itok=D7Tljvd- 1x" type="image/jpeg" width="480"/>
# <source height="212" media="all and (min-width: 768px)" srcset="/sites/default/files/styles/article_teaser/public/media/image/tdt_04102023_wald_internationaler_waldschutz_susanne-gotthardt.jpg?h=7425888e&amp;itok=aA4pz4UU 1x" type="image/jpeg" width="282"/>
# <img alt="Susanne Gotthardt unterstützt den WWF und andere zivilgesellschaftliche Organisationen in Südostasien, die sich für den Erhalt der Biodiversität einsetzen.  " loading="" src="/sites/default/files/styles/article_teaser_mobile/public/media/image/tdt_04102023_wald_internationaler_waldschutz_susanne-gotthardt.jpg?h=7425888e&amp;itok=D7Tljvd-" title="Susanne Gotthardt unterstützt den WWF und andere zivilgesellschaftliche Organisationen in Südostasien, die sich für den Erhalt der Biodiversität einsetzen.  " typeof="foaf:Image"/>
# </picture>
# </a>
# <a class="article-teaser__content" href="/de/topic/umwelt/internationaler-waldschutz-regenwaelder-in-suedostasien-schuetzen">
# <div class="article-teaser__headline">Die Hüter der Wälder </div>
# ...
# <source height="240" media="all and (min-width: 768px)" srcset="/sites/default/files/styles/text_image_teaser/public/media/image/Deutsche-Welle_Logo_2000.jpg?itok=GTokQJcI 1x" type="image/jpeg" width="320"/>
# <img alt="Deutsche Welle" loading="lazy" src="/sites/default/files/styles/text_image_teaser_mobile/public/media/image/Deutsche-Welle_Logo_2000.jpg?itok=0LxG5QDT" title="Deutsche Welle" typeof="foaf:Image"/>
# </picture>
# </span>
# <span class="text-image-teaser__text">
# </span>
# </a>
# </div>
# <div class="text-image-teaser">
# <a class="text-image-teaser__content" href="https://land-der-ideen.de/" rel="noopener" target="_blank">
# <span class="text-image-teaser__image-wrapper">
# <picture>
# <source height="240" media="all and (max-width: 767.98px) and (min-width: 576px)" srcset="/sites/default/files/styles/text_image_teaser/public/media/image/LDI_Logo.jpg?itok=W1wMg6ao 1x" type="image/jpeg" width="320"/>
# <source height="360" media="all and (max-width: 575.98px)" srcset="/sites/default/files/styles/text_image_teaser_mobile/public/media/image/LDI_Logo.jpg?itok=QIXRE6bA 1x" type="image/jpeg" width="480"/>
# <source height="240" media="all and (min-width: 768px)" srcset="/sites/default/files/styles/text_image_teaser/public/media/image/LDI_Logo.jpg?itok=W1wMg6ao 1x" type="image/jpeg" width="320"/>
# <img alt="Deutschland Land der Ideen" loading="lazy" src="/sites/default/files/styles/text_image_teaser_mobile/public/media/image/LDI_Logo.jpg?itok=QIXRE6bA" title="Deutschland Land der Ideen" typeof="foaf:Image"/>
# </picture>
# </span>
# <span class="text-image-teaser__text">
# </span>
# </a>
# </div>
# <div class="text-image-teaser">
# <a class="text-image-teaser__content" href="https://germanyworks.com/" rel="noopener" target="_blank">
# <span class="text-image-teaser__image-wrapper">
# <picture>
# <source height="240" media="all and (max-width: 767.98px) and (min-width: 576px)" srcset="/sites/default/files/styles/text_image_teaser/public/media/image/partnerangebot_germanyworks_logo_0_0.png?itok=mrWE0HmD 1x" type="image/png" width="320"/>
# <source height="360" media="all and (max-width: 575.98px)" srcset="/sites/default/files/styles/text_image_teaser_mobile/public/media/image/partnerangebot_germanyworks_logo_0_0.png?itok=x87xgsMd 1x" type="image/png" width="480"/>
# <source height="240" media="all and (min-width: 768px)" srcset="/sites/default/files/styles/text_image_teaser/public/media/image/partnerangebot_germanyworks_logo_0_0.png?itok=mrWE0HmD 1x" type="image/png" width="320"/>
# <img alt="Germany Works" loading="lazy" src="/sites/default/files/styles/text_image_teaser_mobile/public/media/image/partnerangebot_germanyworks_logo_0_0.png?itok=x87xgsMd" title="Germany Works" typeof="foaf:Image"/>
# </picture>
# </span>
# <span class="text-image-teaser__text">
# </span>
# </a>
# </div>
# <div class="text-image-teaser">
# <a class="text-image-teaser__content" href="https://www.ifa.de/" rel="noopener" target="_blank">
# <span class="text-image-teaser__image-wrapper">
# <picture>
# <source height="240" media="all and (max-width: 767.98px) and (min-width: 576px)" srcset="/sites/default/files/styles/text_image_teaser/public/media/image/ifa_Logo_2000.jpg?itok=IvfpIcZp 1x" type="image/jpeg" width="320"/>
# <source height="360" media="all and (max-width: 575.98px)" srcset="/sites/default/files/styles/text_image_teaser_mobile/public/media/image/ifa_Logo_2000.jpg?itok=br77urlz 1x" type="image/jpeg" width="480"/>
# <source height="240" media="all and (min-width: 768px)" srcset="/sites/default/files/styles/text_image_teaser/public/media/image/ifa_Logo_2000.jpg?itok=IvfpIcZp 1x" type="image/jpeg" width="320"/>
# <img alt="ifa" loading="lazy" src="/sites/default/files/styles/text_image_teaser_mobile/public/media/image/ifa_Logo_2000.jpg?itok=br77urlz" title="ifa" typeof="foaf:Image"/>
# </picture>
# </span>
# <span class="text-image-teaser__text">
# </span>
# </a>
# </div>
# <div class="text-image-teaser">
# <a class="text-image-teaser__content" href="https://www.daad.de/de/" rel="noopener" target="_blank">
# <span class="text-image-teaser__image-wrapper">
# <picture>
# <source height="240" media="all and (max-width: 767.98px) and (min-width: 576px)" srcset="/sites/default/files/styles/text_image_teaser/public/media/image/daad_neueslogorund_1.jpg?itok=IQBJr2Gi 1x" type="image/jpeg" width="320"/>
# <source height="360" media="all and (max-width: 575.98px)" srcset="/sites/default/files/styles/text_image_teaser_mobile/public/media/image/daad_neueslogorund_1.jpg?itok=3PVrQG4l 1x" type="image/jpeg" width="480"/>
# <source height="240" media="all and (min-width: 768px)" srcset="/sites/default/files/styles/text_image_teaser/public/media/image/daad_neueslogorund_1.jpg?itok=IQBJr2Gi 1x" type="image/jpeg" width="320"/>
# <img alt="DAAD" loading="lazy" src="/sites/default/files/styles/text_image_teaser_mobile/public/media/image/daad_neueslogorund_1.jpg?itok=3PVrQG4l" title="DAAD" typeof="foaf:Image"/>
# </picture>
# </span>
# <span class="text-image-teaser__text">
# </span>
# </a>
# </div>
# <div class="text-image-teaser">
# <a class="text-image-teaser__content" href="https://www.alumniportal-deutschland.org/de/" rel="noopener" target="_blank">
# <span class="text-image-teaser__image-wrapper">
# <picture>
# <source height="240" media="all and (max-width: 767.98px) and (min-width: 576px)" srcset="/sites/default/files/styles/text_image_teaser/public/media/image/Alumniportal-Logo-2000.jpg?itok=8RKS-19- 1x" type="image/jpeg" width="320"/>
# <source height="360" media="all and (max-width: 575.98px)" srcset="/sites/default/files/styles/text_image_teaser_mobile/public/media/image/Alumniportal-Logo-2000.jpg?itok=fTgHtRAg 1x" type="image/jpeg" width="480"/>
# <source height="240" media="all and (min-width: 768px)" srcset="/sites/default/files/styles/text_image_teaser/public/media/image/Alumniportal-Logo-2000.jpg?itok=8RKS-19- 1x" type="image/jpeg" width="320"/>
# <img alt="Alumniportal" loading="lazy" src="/sites/default/files/styles/text_image_teaser_mobile/public/media/image/Alumniportal-Logo-2000.jpg?itok=fTgHtRAg" title="Alumniportal" typeof="foaf:Image"/>
# </picture>
# </span>
# <span class="text-image-teaser__text">
# </span>
# </a>
# </div>
# <div class="text-image-teaser">
# <a class="text-image-teaser__content" href="https://www.dandc.eu/de" rel="noopener" target="_blank">
# <span class="text-image-teaser__image-wrapper">
# <picture>
# <source height="240" media="all and (max-width: 767.98px) and (min-width: 576px)" srcset="/sites/default/files/styles/text_image_teaser/public/media/image/partnerangebot_eundz_logo_0_0.jpg?itok=QG_4LVAn 1x" type="image/jpeg" width="320"/>
# <source height="360" media="all and (max-width: 575.98px)" srcset="/sites/default/files/styles/text_image_teaser_mobile/public/media/image/partnerangebot_eundz_logo_0_0.jpg?itok=w7ssi4SW 1x" type="image/jpeg" width="480"/>
# <source height="240" media="all and (min-width: 768px)" srcset="/sites/default/files/styles/text_image_teaser/public/media/image/partnerangebot_eundz_logo_0_0.jpg?itok=QG_4LVAn 1x" type="image/jpeg" width="320"/>
# <img alt="E+Z" loading="lazy" src="/sites/default/files/styles/text_image_teaser_mobile/public/media/image/partnerangebot_eundz_logo_0_0.jpg?itok=w7ssi4SW" title="E+Z" typeof="foaf:Image"/>
# </picture>
# </span>
# <span class="text-image-teaser__text">
# </span>
# </a>
# </div>
# <div class="text-image-teaser">
# <a class="text-image-teaser__content" href="https://www.tatsachen-ueber-deutschland.de/de" rel="noopener" target="_blank">
# <span class="text-image-teaser__image-wrapper">
# <picture>
# <source height="240" media="all and (max-width: 767.98px) and (min-width: 576px)" srcset="/sites/default/files/styles/text_image_teaser/public/media/image/Partnerangebot_tatsachen_Logo_0.jpg?itok=E1t43PWp 1x" type="image/jpeg" width="320"/>
# <source height="360" media="all and (max-width: 575.98px)" srcset="/sites/default/files/styles/text_image_teaser_mobile/public/media/image/Partnerangebot_tatsachen_Logo_0.jpg?itok=WGnPNjAw 1x" type="image/jpeg" width="480"/>
# <source height="240" media="all and (min-width: 768px)" srcset="/sites/default/files/styles/text_image_teaser/public/media/image/Partnerangebot_tatsachen_Logo_0.jpg?itok=E1t43PWp 1x" type="image/jpeg" width="320"/>
# <img alt="Tatsachen über Deutschland" loading="lazy" src="/sites/default/files/styles/text_image_teaser_mobile/public/media/image/Partnerangebot_tatsachen_Logo_0.jpg?itok=WGnPNjAw" title="Tatsachen über Deutschland" typeof="foaf:Image"/>
# </picture>
# </span>
# <span class="text-image-teaser__text">
# </span>
# </a>
# </div>
# </div>
# </div>
# <div class="carousel__controls">
# <button class="carousel-button carousel-button--prev">
# <span class="screen-reader-text">Vorheriges Item</span>
# </button>
# <button class="carousel-button">
# <span class="screen-reader-text">Nächstes Item</span>
# </button>
# </div>
# <div class="carousel__nav"></div>
# </div>
# </div>
# <div class="overlay overlay--immersive">
# <div class="overlay__backdrop">
# <div class="overlay__container">
# <a class="overlay__closeButton" href="#">
# <span class="overlay__close">
# <span class="screen-reader-text">Overlay schließen</span>
# </span>
# </a>
# <div class="overlay__content">
# <div class="text-image-overlay-carousel">
# <div class="carousel carousel--nav-bottom carousel--controls-outside" data-item-count-max="1">
# <div class="carousel__slider">
# <div class="carousel__items">
# <div class="text-image-overlay-carousel__img-wrapper">
# <picture>
# <img alt="Goethe-Institut" loading="lazy" src="/sites/default/files/styles/text_image_overlay_carousel/public/media/image/Goethe-Institut_Logo_2000.jpg?itok=yrQ8_1vj" title="Goethe-Institut" typeof="foaf:Image"/>
# </picture>
# </div>
# <div class="text-image-overlay-carousel__img-wrapper">
# <picture>
# <img alt="Deutsche Welle" loading="lazy" src="/sites/default/files/styles/text_image_overlay_carousel/public/media/image/Deutsche-Welle_Logo_2000.jpg?itok=YIBsaexn" title="Deutsche Welle" typeof="foaf:Image"/>
# </picture>
# </div>
# <div class="text-image-overlay-carousel__img-wrapper">
# <picture>
# <img alt="Deutschland Land der Ideen" loading="lazy" src="/sites/default/files/styles/text_image_overlay_carousel/public/media/image/LDI_Logo.jpg?itok=h0_OLdkW" title="Deutschland Land der Ideen" typeof="foaf:Image"/>
# </picture>
# </div>
# <div class="text-image-overlay-carousel__img-wrapper">
# <picture>
# <img alt="Germany Works" loading="lazy" src="/sites/default/files/styles/text_image_overlay_carousel/public/media/image/partnerangebot_germanyworks_logo_0_0.png?itok=NiencY8A" title="Germany Works" typeof="foaf:Image"/>
# </picture>
# </div>
# <div class="text-image-overlay-carousel__img-wrapper">
# <picture>
# <img alt="ifa" loading="lazy" src="/sites/default/files/styles/text_image_overlay_carousel/public/media/image/ifa_Logo_2000.jpg?itok=WqeWOAOM" title="ifa" typeof="foaf:Image"/>
# </picture>
# </div>
# <div class="text-image-overlay-carousel__img-wrapper">
# <picture>
# <img alt="DAAD" loading="lazy" src="/sites/default/files/styles/text_image_overlay_carousel/public/media/image/daad_neueslogorund_1.jpg?itok=PXfAjz3Q" title="DAAD" typeof="foaf:Image"/>
# </picture>
# </div>
# <div class="text-image-overlay-carousel__img-wrapper">
# <picture>
# <img alt="Alumniportal" loading="lazy" src="/sites/default/files/styles/text_image_overlay_carousel/public/media/image/Alumniportal-Logo-2000.jpg?itok=uxe8xVrx" title="Alumniportal" typeof="foaf:Image"/>
# </picture>
# </div>
# <div class="text-image-overlay-carousel__img-wrapper">
# <picture>
# <img alt="E+Z" loading="lazy" src="/sites/default/files/styles/text_image_overlay_carousel/public/media/image/partnerangebot_eundz_logo_0_0.jpg?itok=QvmCa1_H" title="E+Z" typeof="foaf:Image"/>
# </picture>
# </div>
# <div class="text-image-overlay-carousel__img-wrapper">
# <picture>
# <img alt="Tatsachen über Deutschland" loading="lazy" src="/sites/default/files/styles/text_image_overlay_carousel/public/media/image/Partnerangebot_tatsachen_Logo_0.jpg?itok=az2t0w2d" title="Tatsachen über Deutschland" typeof="foaf:Image"/>
# </picture>
# </div>
# </div>
# </div>
# <div class="carousel__controls">
# <button class="carousel-button carousel-button--prev">
# <span class="screen-reader-text">Vorheriges Item</span>
# </button>
# <button class="carousel-button">
# <span class="screen-reader-text">Nächstes Item</span>
# </button>
# </div>
# <div class="carousel__nav"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="component component--section-start" id="47003">
# <div class="component__inner">
# <div class="single-link-teaser single-link-teaser--image">
# <div class="single-link-teaser__image-wrapper">
# <img alt="Servicefinder" height="200" loading="lazy" src="/sites/default/files/styles/single_link_teaser/public/media/image/such_icon_3.jpg?itok=0qyoAx06" title="Servicefinder" typeof="foaf:Image" width="200"/>
# </div>
# <div class="single-link-teaser__content">
# <div class="single-link-teaser__headline">Finde alles, was du suchst!</div>
# <div class="single-link-teaser__summary">Alle Infos und Services auf einem Blick</div>
# <div class="single-link-teaser__button">
# <a class="button button--secondary button--colorful" data-label="Zum Servicefinder" href="/de/unser-servicefinder">
# 		Zum Servicefinder
# 	</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </main>
# <footer class="footer">
# <div class="footer__inner">
# <div class="footer__content">
# <a class="footer__logo" href="/">
# <span class="screen-reader-text">Zur Startseite wechseln</span>
# </a>
# <nav aria-label="Fußbereichsmenü" class="footer__navigation">
# <ul class="footer__items">
# <li class="footer__item">
# <a class="footer__link" href="/de/form/contact">Kontakt</a>
# </li>
# <li class="footer__item">
# <a class="footer__link" href="/de/datenschutzerklaerung">Datenschutzerklärung</a>
# </li>
# <li class="footer__item">
# <a class="footer__link" href="/de/impressum">Impressum</a>
# </li>
# <li class="footer__item">
# <a class="footer__link" href="/de/app">deutschland.de App</a>
# </li>
# <li class="footer__item">
# <a class="footer__link" href="https://www.deutschland.de/de/newsletter-deutschland" rel="noopener" target="_blank">Newsletter</a>
# </li>
# <li class="footer__item">
# <a class="footer__link" href="/de/service-fuer-journalisten">Service für Journalisten</a>
# </li>
# <li class="footer__item">
# <a class="footer__link" href="/de/erklaerung-zur-barrierefreiheit">Erklärung zur Barrierefreiheit</a>
# </li>
# <li class="footer__item">
# <a class="footer__signLanguageButton" href="https://www.deutschland.de/de/videoseite-deutschlandde-in-gebaerdensprache">
# <span class="screen-reader-text">International sign language</span>
# </a>
# </li>
# <li class="footer__item">
# <a class="footer__easyReadButton" href="https://www.deutschland.de/de/informationen-in-leichter-sprache">
# <span class="screen-reader-text">Easy Read</span>
# </a>
# </li>
# </ul>
# </nav>
# </div>
# <div class="footer__meta">
# <a class="footer__neutralLogo" href="https://www.climatepartner.com/16820-2202-1001">
# <span class="screen-reader-text">Zur Website wechseln</span>
# </a>
# </div>
# </div>
# </footer>
# </div>
# <script data-drupal-selector="drupal-settings-json" type="application/json">{"path":{"baseUrl":"\/","scriptPath":null,"pathPrefix":"de\/","currentPath":"node\/4","currentPathIsAdmin":false,"isFront":true,"currentLanguage":"de"},"pluralDelimiter":"\u0003","suppressDeprecationErrors":true,"lazy":{"lazysizes":{"lazyClass":"lazyload","loadedClass":"lazyloaded","loadingClass":"lazyloading","preloadClass":"lazypreload","errorClass":"lazyerror","autosizesClass":"lazyautosizes","srcAttr":"data-src","srcsetAttr":"data-srcset","sizesAttr":"data-sizes","minSize":40,"customMedia":[],"init":true,"expFactor":1.5,"hFac":0.8,"loadMode":2,"loadHidden":true,"ricTimeout":0,"throttleDelay":125,"plugins":[]},"placeholderSrc":"","preferNative":false,"minified":true,"libraryPath":"\/libraries\/lazysizes"},"ajaxTrustedUrl":{"form_action_p_pvdeGsVG5zNF_XLGPTvYSKCf43t8qZYSwcfZl2uzM":true},"user":{"uid":0,"permissionsHash":"5fd861a350e50bea7ba508e94c6dab1ce88873a4b792160a94eb78efdfeb7a94"}}</script>
# <script src="/sites/default/files/js/js_CSpaPtMGDGlXmucCDNOnA2tq2Xpv76Nql-wEg-cmOco.js"></script>
# </body>
# </html>

# %%
soup.select('.article-teaser__summary')
# Out:
# [<div class="article-teaser__summary">Der Wald muss sich an  Klimaerwärmung und Extremwetter anpassen. Wir erklären, wie das gelingen kann.  </div>,
#  <div class="article-teaser__summary">Weltweit leiden die Wälder unter illegaler Abholzung. Waldexpertin Susanne Gotthardt erklärt, wie der WWF Wälder in Südostasien rettet. </div>,
#  <div class="article-teaser__summary">Was braucht der Wald, wenn sich das Klima verändert? Das versucht das Projekt FutureForest mit Hilfe von KI zu ermitteln. </div>,
#  <div class="article-teaser__summary">Die Deutschen und ihr Wald – hier liest du einen kleinen Countdown über eine besonders emotionale Beziehung.</div>,
#  <div class="article-teaser__summary">Wenn du diese erstaunlichen Fakten kennst, kannst du bei jeder Diskussion über den deutschen Wald mitreden.</div>,
#  <div class="article-teaser__summary">Gülsah Wilke hat eine klare Mission: die deutsche Tech-Szene diverser zu machen. Wie sie das mit dem Verein 2hearts schaffen will, lest ihr hier.</div>,
#  <div class="article-teaser__summary">Eine nationale Wasserstoffstrategie soll dazu beitragen, die Nutzung von grünem Wasserstoff in der deutschen Wirtschaft voranzubringen.</div>,
#  <div class="article-teaser__summary">Das Fairwork-Projekt der GIZ sorgt in 24 Ländern für bessere Arbeitsbedingungen bei Beschäftigten digitaler Plattformen. </div>,
#  <div class="article-teaser__summary">Deutsche Unternehmen und Forschungsinstitute wollen mit dem Projekt HygO mit moderner Wasserstoff-Technologie die Stromversorgung verbessern.</div>,
#  <div class="article-teaser__summary">Digitalisierung und künstliche Intelligenz können dabei helfen, globale Lieferketten sicherer, transparenter und nachhaltiger zu gestalten. </div>,
#  <div class="article-teaser__summary">Drei erfolgreiche Frauen in der Führungsspitze von Weltkonzernen: Lernen Sie Bettina Orlopp, Belén Garijo und Melanie Kreis kennen. </div>,
#  <div class="article-teaser__summary">Warum die Forschungsinvestitionen deutscher Unternehmen im Ausland allen Seiten nutzen können, erklärt Wirtschaftswissenschaftlerin Heike Belitz. </div>]

# %% [markdown]
# Now lets parse the spanish site as well

# %%
result = requests.get(country_newspapers['Spain'])
soup = bs4.BeautifulSoup(result.text, 'lxml')

# %%
len(soup.select('.c_t')) # Check the headlines
# Out:
# 142

# %%
soup.select('.c_t')[:3] # Take the first three
# Out:
# [<h2 class="c_t"><a href="https://elpais.com/internacional/2023-10-10/guerra-entre-israel-y-gaza-en-directo.html">Israel recupera el control de la frontera y afirma haber hallado 1.500 cadáveres de milicianos de Hamás</a></h2>,
#  <h2 class="c_t"><a href="https://elpais.com/internacional/2023-10-09/israel-cerca-por-completo-gaza-para-asfixiar-a-hamas-tras-16-anos-de-bloqueo.html"><span class="c_t_i c_t_i-s _pr" name="elpais_ico"></span>Asedio total de la Franja para asfixiar a Hamás tras 16 años de bloqueo</a></h2>,
#  <h2 class="c_t"><a href="https://elpais.com/internacional/2023-10-09/la-escalada-entre-hamas-e-israel-pone-a-prueba-a-los-tradicionales-mediadores-de-la-region.html"><span class="c_t_i c_t_i-s _pr" name="elpais_ico"></span>La escalada del conflicto pone a prueba a los tradicionales mediadores de la región</a></h2>]

# %% [markdown]
# ### Grabbing Text

# %%
for tag in soup.select('.c_t')[:3]:
    print(tag.text)
# Out:
# Israel recupera el control de la frontera y afirma haber hallado 1.500 cadáveres de milicianos de Hamás
# Asedio total de la Franja para asfixiar a Hamás tras 16 años de bloqueo
# La escalada del conflicto pone a prueba a los tradicionales mediadores de la región

# %%
# We will combine these respective tags and the URL in the dictionary
country_newspapers = {"Spain":('https://elpais.com/','.c_t'),
                      "France":("https://www.lemonde.fr/",'.article__title-label'),
                      "Netherlands":("https://www.deutschland.de/de/",'.article-teaser__summary')
                      }

# %% [markdown]
# ### Translation via OpenAI

# %%
''' Create the prompt '''
def create_prompt():
    # Get Country
    country = input(f"What country would you like the news summary for ?")
    # Get Country's URL newspaper and the respective tag
    try:
        url, tag = country_newspapers[country]
    except:
        print(f"Sorry that country is not supported!!")
        return
    
    # Scrape the website
    results = requests.get(url)
    soup = bs4.BeautifulSoup(results.text, 'lxml')
    
    # Grab all the text together
    country_headline = ""
    for item in soup.select(tag)[:3]:
        country_headline += item.getText()+"\n"
    
    final_prompt = "Detect the language of the news headline below and then translate a summary in English in a conversational tone:\n" + country_headline
    return final_prompt

# %%
final_prompt = create_prompt()
print(final_prompt)
# Out:
# Detect the language of the news headline below and then translate a summary in English in a conversational tone:
# Israel recupera el control de la frontera de Gaza y afirma haber hallado 1.500 cadáveres de milicianos de Hamás
# Asedio total de la Franja para asfixiar a Hamás tras 16 años de bloqueo
# La escalada del conflicto pone a prueba a los tradicionales mediadores de la región

# %%
# Get the OpenAPI Key
openai.api_key = os.getenv("OPENAI_API_KEY")

# %%
response = openai.Completion.create(engine='text-davinci-003',
                                    prompt = final_prompt,
                                    temperature = 0.1,
                                    max_tokens = 200,
                                    top_p = 1.0,
                                    frequency_penalty=0.0,
                                    presence_penalty=0.0
                                    )

# %%
# Check the response
print(response['choices'][0]['text'])
# Out:
# The headline is in Spanish. Translated to English, it reads: Israel has regained control of the Gaza border and claims to have found 1,500 corpses of Hamas militants. A total siege of the Strip to choke Hamas after 16 years of blockade has escalated the conflict, testing the region's traditional mediators.
