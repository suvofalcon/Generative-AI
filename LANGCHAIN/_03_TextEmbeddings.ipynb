# %% [markdown]
# # Text Embeddings Example

# %%
import os
import pandas as pd
from langchain.llms import OpenAI
from langchain.embeddings import OpenAIEmbeddings
from openai.embeddings_utils import cosine_similarity

# %%
# Set the database path

data_path = os.getenv("AI_DATASETS_PATH")
full_path = os.path.join(data_path, "genai_datasets/data.xlsx")

# Initialize the OpenAI Key
OpenAI.openai_api_key = os.getenv("OPENAI_API_KEY")

# %%
# Initialize OpenAI embeddings
embeddings = OpenAIEmbeddings()

# %%
# read the dataset
df = pd.read_excel(full_path)
df.head()
# Out:
#    Unnamed: 0    Words
# 0           0   Schhol
# 1           1  College
# 2           2      Car
# 3           3     Bike
# 4           4    Apple

# %%
# Now we will add one more column and apply embeddings for each entry, and then we create a csv
df['embedding'] = df['Words'].apply(lambda entries: embeddings.embed_query(entries))
df.to_csv('word_embeddings.csv')

# %%
df.head()
# Out:
#    Unnamed: 0    Words                                          embedding
# 0           0   Schhol  [0.006822214127775622, 0.007156308832786324, -...
# 1           1  College  [0.008567630960204773, -0.009737508048176517, ...
# 2           2      Car  [-0.004958966229655546, -0.012322071811467243,...
# 3           3     Bike  [0.0054756435753999765, -0.0136203037636246, -...
# 4           4    Apple  [0.014477049403261352, -0.003934278727982006, ...

# %%
# Now lets get embeddings for our text
our_text = "mango"
text_embedding = embeddings.embed_query(our_text)
print(text_embedding)
# Out:
# [-0.008513468245413543, -0.026108840258799254, 0.009153774861767678, -0.02085570973334096, 0.0054458751812192846, 0.009787548250316346, -0.03311301367186194, -0.01835981927126934, -0.004361274149497306, -0.03167558807066145, 0.0029238504109419545, 0.008990431128115128, -0.004155461175480254, 0.019862580875814738, -0.01957509650063269, 0.004358007069933291, 0.030969945450962405, -0.004305737056538023, 0.012538254154574989, -0.02000632306340576, -0.00983981779805033, 0.006762424892147873, -0.0011964918711162267, -0.019274543807194587, 0.0004426611375203088, 0.00260696371666762, 0.027781478824802665, -0.011773805965368794, 0.008003836429716936, 0.0067166885722193545, 0.043619274722778524, -0.014112886852915897, -0.006200522597394715, -0.005053850779246707, -0.008258651871903956, -0.0016081177027350109, -0.002551426856538979, -0.011675800097706291, -0.0017559436233657313, -0.016164481502635823, 0.01357711933202973, -0.021456815120217174, -0.018255280175801372, -0.015785524487596743, -0.017157610360162046, 0.016216751050369807, -0.0050799855531136985, -0.019470555542519592, -0.036667368994804696, 0.007755553749674097, 0.00509632001961121, 0.014766260856203526, -0.016282088916359853, -0.0006562328725291244, -0.00500158076585144, 0.002270475941993042, -0.007886229015992906, 0.02000632306340576, -0.003008788891670961, 0.008709479980738549, 0.0012797970448938673, 0.020476752718301877, -0.026840619515010426, 0.011564726843110293, 0.0035478227936292183, -0.003783037621077278, -0.0021087657481225004, -0.016360495100605964, 0.021496016349695092, 0.01428276381437391, 0.025664545377770125, 0.01213969559347438, 0.003965982667960713, 0.0151713526451096, 0.014125954239849393, 0.0027768411437869168, -0.0280950979738517, -0.0038614426411701787, -0.006213590449989495, 0.0016857058365215866, 0.03347890423129009, -0.020346078848966918, -0.006056780409803694, 0.0171968134522851, 0.02135227416210407, 0.004609556363878862, -0.002755606523604665, 0.0005002397768573085, 0.001065000184152376, -0.02416178377322473, 0.0012381444580050471, -0.0007775155179320304, 0.02468448297585483, 0.006860430759810376, -0.023782826758185646, -0.003590292266824363, -0.002758873370338039, 0.01775871574703826, -0.003482485393300455, -0.03146650987972552, -0.018425157137259385, 0.009565400809801783, -0.020476752718301877, -0.0028307444641335502, -0.02712810389019247, -0.0011091029642988873, 0.015354297924823675, -0.00735046149510674, 0.030133625236638133, -0.026866754288877418, -0.006285461543785006, 0.021365342480360133, 0.010636934920251548, -0.049238293945019836, -0.018451291911126377, -0.02759853354508859, 0.0035478227936292183, 0.015210555737232654, 0.0035510896403625923, -0.024240189957470838, -0.00485130488479367, 0.016151415047024893, 0.028225773705831795, -0.013733928906554248, 0.01873877628630842, -0.01357711933202973, -0.0003401630354572845, -0.018791047696687536, -0.015040677844452075, -0.018163807535944335, 0.03800025177524694, 0.007794756376135868, 0.0074876704548922975, 0.009872486731045352, 0.003769970234143782, 0.013707794132687256, -0.03559583395303236, 0.007076044506858193, -0.013054420129399627, -0.023090250594097528, 0.00778822268266912, 0.022018715552325197, -0.012512119380707997, -0.013746997224810311, -0.012884542236619046, 0.01728828609214214, 0.045579395801318846, 0.03010749046277114, 0.008500400858480047, -0.007742486362740601, 0.018960924658145552, -0.028826877230062872, 0.024018041585633705, 0.0036294946604554924, 0.016608776383664953, 0.009624204516663798, -0.0015803492726706903, 0.0012111927978317304, -0.0074811367614255496, 0.005798697422391374, 0.010068499397692925, -0.022606752620945348, -0.012642794181365522, -0.012322640873188455, 0.002734371670591772, 0.027363318717640528, 0.011584327457849252, -0.007579142629088052, 0.010650002307185043, -0.01102242609441866, -0.0023880833557170717, 0.034445896452304184, -0.023351600195412582, 0.031544916063971626, 0.01275386743596152, 0.01470092299021348, 0.012760401595089552, 0.016765586889512036, 0.008 ...

# %% [markdown]
# #### We can determine how similar a word is to other words in our dataframe after we have a vector representing that word. By computing the cosine similarity of the word vector for our search term to each word embedding in our dataframe.

# %%
df['similarity_score'] = df['embedding'].apply(lambda vectors: cosine_similarity(vectors, text_embedding))

# %%
df.sort_values('similarity_score', ascending=False, inplace=True)
df
# Out:
#    Unnamed: 0    Words                                          embedding  \
# 6           6   Banana  [-0.012999765903696864, -0.01998321619391984, ...
# 5           5  Orange   [0.013119571182465328, -0.028533135200008802, ...
# 4           4    Apple  [0.014477049403261352, -0.003934278727982006, ...
# 3           3     Bike  [0.0054756435753999765, -0.0136203037636246, -...
# 1           1  College  [0.008567630960204773, -0.009737508048176517, ...
# 2           2      Car  [-0.004958966229655546, -0.012322071811467243,...
# 0           0   Schhol  [0.006822214127775622, 0.007156308832786324, -...
#
#    similarity_score
# 6          0.886140
# 5          0.843678
# 4          0.802333
# 3          0.783956
# 1          0.770327
# 2          0.770040
# 0          0.764293

# %%
# to get the largest value
df.nlargest(1, 'similarity_score').iloc[0]
# Out:
# Unnamed: 0                                                          6
# Words                                                          Banana
# embedding           [-0.012999765903696864, -0.01998321619391984, ...
# similarity_score                                              0.88614
# Name: 6, dtype: object
